# %%
import pymongo
from pymongo import MongoClient
import pprint
import re
from IPython.display import clear_output
import connect as c
# Replace XXXX with your connection URI from the Atlas UI
client = c.getMongoClient()

pipeline = [
    {
        '$match': {'language': 'English Korean'}
    }
]

clear_output()
pprint.pprint(list(client.mflix.movies_initial.aggregate(pipeline)))
# Out:
# [{'_id': ObjectId('614b7553708918ab1807865c'),
#   'awards': '',
#   'cast': 'Rock Hudson Anna Kashfi Dan Duryea Don DeFore',
#   'country': 'USA',
#   'director': 'Douglas Sirk',
#   'fullplot': 'Dean Hess who entered the ministry to atone for bombing a '
#               "German orphanage decides he's a failure at preaching. Rejoined "
#               'to train pilots early in the Korean War he finds Korean orphans '
#               'raiding the airbase garbage. With a pretty Korean teacher he '
#               'sets up an orphanage for them and others. But he finds that to '
#               'protect his charges he has to kill.',
#   'genre': 'Biography Drama History',
#   'imdbID': '50171',
#   'imdbRating': '6.3',
#   'imdbVotes': '654',
#   'language': 'English Korean',
#   'lastupdated': '25:52.3',
#   'metacritic': '',
#   'plot': 'A remorseful bomber pilot-turned-minister rejoins for the Korean '
#           'War.',
#   'poster': 'https://m.media-amazon.com/images/M/MV5BMTIwMjIzNTYzMl5BMl5BanBnXkFtZTcwOTIxMTUyMQ@@._V1_SX300.jpg',
#   'rating': 'APPROVED',
#   'released': '03-03-1957',
#   'runtime': '108 min',
#   'title': 'Battle Hymn',
#   'type': 'movie',
#   'writer': 'Charles Grayson Vincent B. Evans',
#   'year': '1957'},
#  {'_id': ObjectId('614b7553708918ab18078718'),
#   'awards': '',
#   'cast': 'Richard Widmark Richard Basehart Dolores Michaels June Lockhart',
#   'country': 'USA',
#   'director': 'Karl Malden',
#   'fullplot': 'Military investigator Colonel Edwards is assigned a case '
#               'involving Major Cargill a Korean War POW who is accused of '
#               "treason. Although Cargill admits his guilt and Edwards' "
#               'superiors are impatiently pushing Edwards to move this case to '
#               "court martial Edwards becomes convinced of Cargill's innocence.",
#   'genre': 'Drama War',
#   'imdbID': '51083',
#   'imdbRating': '7.3',
#   'imdbVotes': '719',
#   'language': 'English Korean',
#   'lastupdated': '01:14.6',
#   'metacritic': '',
#   'plot': 'During the Korean War former POW Major Cargill admits to having '
#           'collaborated with the enemy but military investigator Colonel '
#           'Edwards wants the details.',
#   'poster': 'https://m.media-amazon.com/images/M/MV5BMTU2NzU1Nzg5Nl5BMl5BanBnXkFtZTcwMjgyMTM4NA@@._V1_SX300.jpg',
#   'rating': 'APPROVED',
#   'released': '23-10-1957',
#   'runtime': '96 min',
#   'title': 'Time Limit',
#   'type': 'movie',
#   'writer': 'Henry Denker (screenplay) Henry Denker (play) Ralph Berkey (play)',
#   'year': '1957'},
#  {'_id': ObjectId('614b7553708918ab18078922'),
#   'awards': '2 nominations.',
#   'cast': "Tony Curtis Karl Malden Edmond O'Brien Arthur O'Connell",
#   'country': 'USA',
#   'director': 'Robert Mulligan',
#   'fullplot': "Based on a true story a bright young man who hasn't the "
#               'patience for the normal way of advancement finds that people '
#               'rarely question you if your papers are in order. He becomes a '
#               'marine a monk a surgeon onboard a Canadian Warship and a prison '
#               'warden.',
#   'genre': 'Comedy Drama',
#   'imdbID': '53879',
#   'imdbRating': '7.1',
#   'imdbVotes': '710',
#   'language': 'English Korean',
#   'lastupdated': '03:39.4',
#   'metacritic': '',
#   'plot': "Based on a true story a bright young man who hasn't the patience "
#           'for the normal way of advancement finds that people rarely question '
#           'you if your papers are in order. He becomes a marine a...',
#   'poster': 'https://m.media-amazon.com/images/M/MV5BMTUyMzI3MjM5N15BMl5BanBnXkFtZTcwNTQ3MDAyMQ@@._V1_SX300.jpg',
#   'rating': '',
#   'released': '03-02-1961',
#   'runtime': '113 min',
#   'title': 'The Great Impostor',
#   'type': 'movie',
#   'writer': "Robert Crichton (novel) Liam O'Brien (screenplay)",
#   'year': '1961'},
#  {'_id': ObjectId('614b7557708918ab18079b88'),
#   'awards': '',
#   'cast': 'Marilyn Joi Saul Kahan David Zucker Marcy Goldman',
#   'country': 'USA',
#   'director': 'John Landis',
#   'fullplot': 'A series of loosely connected skits that spoof news programs '
#               'commercials porno films kung fu films disaster films '
#               'blaxploitation films spy films mafia films and the fear that '
#               'somebody is watching you on the other side of the TV.',
#   'genre': 'Comedy',
#   'imdbID': '76257',
#   'imdbRating': '6.5',
#   'imdbVotes': '13230',
#   'language': 'English Korean',
#   'lastupdated': '10:49.3',
#   'metacritic': '',
#   'plot': 'Series of short highly irreverent and quite often tasteless skits.',
#   'poster': 'https://m.media-amazon.com/images/M/MV5BMTA5MTAwNDI1MjBeQTJeQWpwZ15BbWU2MDk3MjY3OQ@@._V1_SX300.jpg',
#   'rating': 'R',
#   'released': '10-08-1977',
#   'runtime': '83 min',
#   'title': 'The Kentucky Fried Movie',
#   'type': 'movie',
#   'writer': 'David Zucker Jim Abrahams Jerry Zucker',
#   'year': '1977'},
#  {'_id': ObjectId('614b755b708918ab1807af35'),
#   'awards': '',
#   'cast': 'Jeff Speakman John Dye Mako James Hong',
#   'country': 'USA',
#   'director': 'Mark DiSalle',
#   'fullplot': 'Jeff a young delinquent is enrolled by his father in a kenpo '
#               'school in the hopes of teaching the boy some self-discipline. '
#               "Years later Jeff's mentor Kim is being threatened by one of the "
#               'Korean mafia families. Jeff tries to help his old friend but is '
#               "too late to prevent Kim's death at the hands of an unknown "
#               'hitman. Vowing revenge Jeff takes on all of the families using '
#               'his martial arts skills to find the man who killed his friend.',
#   'genre': 'Action Drama',
#   'imdbID': '102655',
#   'imdbRating': '5.9',
#   'imdbVotes': '2399',
#   'language': 'English Korean',
#   'lastupdated': '30:38.5',
#   'metacritic': '',
#   'plot': 'Jeff a young delinquent is enrolled by his father in a kenpo school '
#           'in the hopes of teaching the boy some self-discipline. Years later '
#           "Jeff's mentor Kim is being threatened by one of ...",
#   'poster': 'https://m.media-amazon.com/images/M/MV5BMTQ2ODMxNTc3NV5BMl5BanBnXkFtZTcwODU2MTQyMQ@@._V1_SX300.jpg',
#   'rating': 'R',
#   'released': '15-03-1991',
#   'runtime': '83 min',
#   'title': 'The Perfect Weapon',
#   'type': 'movie',
#   'writer': 'David C. Wilson',
#   'year': '1991'},
#  {'_id': ObjectId('614b755e708918ab1807babf'),
#   'awards': '1 nomination.',
#   'cast': "Treat Williams Famke Janssen Anthony Heald Kevin J. O'Connor",
#   'country': 'USA Canada',
#   'director': 'Stephen Sommers',
#   'fullplot': "When a band of ruthless hijackers invade the world's most "
#               "luxurious cruise ship they're shocked to discover the "
#               "passengers have mysteriously vanished! But that doesn't mean "
#               'they are alone! Something terrifying is lurking just out of '
#               'sight: a deadly force from the unexplored depths of the ocean '
#               'that begins to snatch the horrified intruders one by one!',
#   'genre': 'Action Adventure Horror',
#   'imdbID': '118956',
#   'imdbRating': '6',
#   'imdbVotes': '25178',
#   'language': 'English Korean',
#   'lastupdated': '17:59.9',
#   'metacritic': '',
#   'plot': 'A group of heavily armed hijackers board a luxury ocean liner in '
#           'the South Pacific Ocean to loot it only to do battle with a series '
#           'of large-sized tentacled man-eating sea creatures who have taken '
#           'over the ship first.',
#   'poster': 'https://m.media-amazon.com/images/M/MV5BMTk5MDM5NzM4OF5BMl5BanBnXkFtZTcwNjE1MDAzMQ@@._V1_SX300.jpg',
#   'rating': 'R',
#   'released': '30-01-1998',
#   'runtime': '106 min',
#   'title': 'Deep Rising',
#   'type': 'movie',
#   'writer': 'Stephen Sommers',
#   'year': '1998'},
#  {'_id': ObjectId('614b755e708918ab1807bda2'),
#   'awards': '1 nomination.',
#   'cast': 'David Zaugh James Boobar Burt Bulos Ray Chang',
#   'country': 'USA',
#   'director': 'Chris Chan Lee',
#   'fullplot': 'Eight friends in Los Angeles spend their last evening together '
#               'as they face graduation from high school and the onset of their '
#               'adult lives. One of them gets in unexpected trouble when he '
#               "loses a large sum of his dad's money. The friends rally "
#               'together to attempt to raise the money back in one evening in a '
#               'wild and desperate scavenger hunt.',
#   'genre': 'Comedy Drama Romance',
#   'imdbID': '122804',
#   'imdbRating': '6',
#   'imdbVotes': '193',
#   'language': 'English Korean',
#   'lastupdated': '58:15.3',
#   'metacritic': '',
#   'plot': 'Eight friends in Los Angeles spend their last evening together as '
#           'they face graduation from high school and the onset of their adult '
#           'lives. One of them gets in unexpected trouble when he ...',
#   'poster': 'https://m.media-amazon.com/images/M/MV5BMTA0MzUxOTE1NTleQTJeQWpwZ15BbWU3MDk3MTI2MTE@._V1_SX300.jpg',
#   'rating': 'R',
#   'released': '29-05-1998',
#   'runtime': '90 min',
#   'title': 'Yellow',
#   'type': 'movie',
#   'writer': 'Chris Chan Lee',
#   'year': '1998'},
#  {'_id': ObjectId('614b755f708918ab1807bf67'),
#   'awards': '',
#   'cast': 'Jane March Stephen Mendel Lillo Brancato Nick Mancuso',
#   'country': 'Canada USA',
#   'director': 'Jim Donovan',
#   'fullplot': 'Sook Hee (aka Miya) is a North Korean agent who has infiltrated '
#               'into South Korea in order to steal US military secrets. She is '
#               'hired as a nanny in the family of US Colonel Greg Finn who '
#               'works as an intelligence officer with the US forces in South '
#               "Korea. Col. Finn's teenage son Chris and Miya fall in love with "
#               "each other but Miya's North Korean superiors demand that she "
#               'completes her mission.',
#   'genre': 'Action Drama Thriller',
#   'imdbID': '134912',
#   'imdbRating': '4.8',
#   'imdbVotes': '268',
#   'language': 'English Korean',
#   'lastupdated': '01:40.1',
#   'metacritic': '',
#   'plot': 'In 1994 South Korea a female North Korean spy integrates herself as '
#           'a housekeeper for U.S. military officer to steal classified '
#           'documents but soon worries about her cover when she falls for the '
#           'teenage son of the officer.',
#   'poster': 'https://m.media-amazon.com/images/M/MV5BMjEwODQ0OTU4MV5BMl5BanBnXkFtZTcwMjgyMTYxMQ@@._V1_SX300.jpg',
#   'rating': 'R',
#   'released': '19-05-1998',
#   'runtime': '103 min',
#   'title': 'Provocateur',
#   'type': 'movie',
#   'writer': 'Roger Kumble',
#   'year': '1998'},
#  {'_id': ObjectId('614b7561708918ab1807cb4d'),
#   'awards': '1 win & 1 nomination.',
#   'cast': 'Alveen Borshay Arnold Borshay Deann Borshay',
#   'country': 'USA',
#   'director': 'Deann Borshay',
#   'fullplot': '',
#   'genre': 'Documentary',
#   'imdbID': '240505',
#   'imdbRating': '7.4',
#   'imdbVotes': '32',
#   'language': 'English Korean',
#   'lastupdated': '26:50.3',
#   'metacritic': '',
#   'plot': '',
#   'poster': '',
#   'rating': '',
#   'released': '01-01-2000',
#   'runtime': '',
#   'title': 'First Person Plural',
#   'type': 'movie',
#   'writer': 'Deann Borshay Vivien Hillgrove Gilliam',
#   'year': '2000'},
#  {'_id': ObjectId('614b7563708918ab1807d5d8'),
#   'awards': '3 wins & 9 nominations.',
#   'cast': 'Ben Stiller Owen Wilson Snoop Dogg Fred Williamson',
#   'country': 'USA',
#   'director': 'Todd Phillips',
#   'fullplot': '"Set in the 1970s in a metropolis called ""Bay City"" this is '
#               'the tale of two police detective partners Ken ""Hutch"" '
#               'Hutchinson and Dave Starsky who always seem to get the toughest '
#               'cases from their boss Captain Dobey rely on omniscient street '
#               'informer Huggy Bear and race to the scene of the crimes in '
#               'their souped-up 1974 Ford Torino hot rod telling the story of '
#               'their first big case (as a prequel to the TV show) which '
#               'involved a former college campus drug dealer who went on to '
#               'become a white collar criminal."',
#   'genre': 'Comedy Crime',
#   'imdbID': '335438',
#   'imdbRating': '6.1',
#   'imdbVotes': '115264',
#   'language': 'English Korean',
#   'lastupdated': '13:22.7',
#   'metacritic': '55',
#   'plot': 'Two streetwise cops bust criminals in their red-and-white Ford '
#           'Torino with the help of police snitch called Huggy Bear.',
#   'poster': 'https://m.media-amazon.com/images/M/MV5BMzU2NTQ1NTkxOV5BMl5BanBnXkFtZTcwNTE1MTEzMw@@._V1_SX300.jpg',
#   'rating': 'PG-13',
#   'released': '05-03-2004',
#   'runtime': '101 min',
#   'title': 'Starsky & Hutch',
#   'type': 'movie',
#   'writer': "William Blinn (characters) Stevie Long (story) John O'Brien "
#             "(story) John O'Brien (screenplay) Todd Phillips (screenplay) Scot "
#             'Armstrong (screenplay)',
#   'year': '2004'},
#  {'_id': ObjectId('614b7564708918ab1807d972'),
#   'awards': '1 nomination.',
#   'cast': 'Jason Behr Amanda Brooks Robert Forster Craig Robinson',
#   'country': 'South Korea',
#   'director': 'Hyung-rae Shim',
#   'fullplot': 'Based on the Korean legend unknown creatures will return and '
#               'devastate the planet. Reporter Ethan Kendrick is called in to '
#               'investigate the matter and he arrives at the conclusion that a '
#               'girl stricken with a mysterious illness named Sarah is suppose '
#               'to help him. The Imoogi makes its way to Los Angeles wreaking '
#               'havoc and destruction. With the entire city under arms will '
#               'Ethan and Sarah make it in time to save the people of Los '
#               'Angeles?',
#   'genre': 'Action Drama Fantasy',
#   'imdbID': '372873',
#   'imdbRating': '3.6',
#   'imdbVotes': '21048',
#   'language': 'English Korean',
#   'lastupdated': '36:49.9',
#   'metacritic': '33',
#   'plot': 'Based on the Korean legend unknown creatures will return and '
#           'devastate the planet. Reporter Ethan Kendrick is called in to '
#           'investigate the matter and he arrives at the conclusion that a ...',
#   'poster': 'https://m.media-amazon.com/images/M/MV5BMTc2OTk1MzUzMl5BMl5BanBnXkFtZTcwNjE0ODI1MQ@@._V1_SX300.jpg',
#   'rating': 'PG-13',
#   'released': '14-09-2007',
#   'runtime': '90 min',
#   'title': 'Dragon Wars: D-War',
#   'type': 'movie',
#   'writer': 'Hyung-rae Shim',
#   'year': '2007'},
#  {'_id': ObjectId('614b7564708918ab1807dc19'),
#   'awards': '1 win & 4 nominations.',
#   'cast': 'Vin Diesel Lauren Graham Faith Ford Brittany Snow',
#   'country': 'Canada USA',
#   'director': 'Adam Shankman',
#   'fullplot': 'After a Navy SEAL fails to rescue a scientist who developed a '
#               "top secret device he is assigned to guard the man's children "
#               'while searching for information on where the device may be '
#               'hidden inside the house. Along the way he must cope with '
#               'rebellious teens child care an overbearing school official and '
#               'foreign spies also looking for it.',
#   'genre': 'Action Comedy Drama',
#   'imdbID': '395699',
#   'imdbRating': '5.5',
#   'imdbVotes': '59709',
#   'language': 'English Korean',
#   'lastupdated': '13:19.7',
#   'metacritic': '30',
#   'plot': 'Disgraced Navy SEAL Shane Wolfe is handed a new assignment: Protect '
#           'the five Plummer kids from enemies of their recently deceased '
#           'father -- a government scientist whose top-secret experiment '
#           "remains in the kids' house.",
#   'poster': 'https://m.media-amazon.com/images/M/MV5BMTQ2MTYxNzM3M15BMl5BanBnXkFtZTcwNTEzNTgyMQ@@._V1_SX300.jpg',
#   'rating': 'PG',
#   'released': '04-03-2005',
#   'runtime': '95 min',
#   'title': 'The Pacifier',
#   'type': 'movie',
#   'writer': 'Thomas Lennon Robert Ben Garant',
#   'year': '2005'},
#  {'_id': ObjectId('614b7567708918ab1807e6bb'),
#   'awards': '',
#   'cast': 'Nicholas Gonzalez Matt Bushell Keith David Denis Arndt',
#   'country': 'USA',
#   'director': 'James Dodson',
#   'fullplot': 'The fate of the world hangs in the balance in this explosive '
#               'action thriller. Brace yourself for nonstop action and chilling '
#               "suspense because there's no turning back in this pulse-pounding "
#               'sequel that takes you Behind Enemy Lines for another '
#               'adrenaline-fueled adventure! When a team of U.S. Navy SEALs is '
#               'assigned to destroy a North Korean missile site and avert a '
#               'possible nuclear strike failure is not an option. But the '
#               'mission is abruptly aborted stranding four soldiers in enemy '
#               'territory. Now in order to survive they must defeat the rebel '
#               'forces that threaten their lives their allies and the entire '
#               'free world!',
#   'genre': 'Action Thriller War',
#   'imdbID': '497329',
#   'imdbRating': '4.5',
#   'imdbVotes': '4738',
#   'language': 'English Korean',
#   'lastupdated': '21:40.8',
#   'metacritic': '',
#   'plot': 'Navy SEALS headed by Lt. Bobby James are dispatched to North Korea '
#           'on a covert mission all in an effort to take out a missile site...',
#   'poster': 'https://m.media-amazon.com/images/M/MV5BMTMwODgyNDMzMV5BMl5BanBnXkFtZTcwMDUyNjQzMQ@@._V1_SX300.jpg',
#   'rating': 'R',
#   'released': '17-10-2006',
#   'runtime': '96 min',
#   'title': 'Behind Enemy Lines II: Axis of Evil',
#   'type': 'movie',
#   'writer': 'James Dodson',
#   'year': '2006'},
#  {'_id': ObjectId('614b7569708918ab1807f2c2'),
#   'awards': '2 nominations.',
#   'cast': 'Hye-kyo Song Arno Frisch Athena Currey June Kyoto Lu',
#   'country': 'USA',
#   'director': 'Soopum Sohn',
#   'fullplot': "A Korean emigrant's superstitiously suspicious past starts to "
#               'catch up with her as her obsession with her married American '
#               'neighbors begins to twist out of control and off the deep end.',
#   'genre': 'Thriller',
#   'imdbID': '1145152',
#   'imdbRating': '4.8',
#   'imdbVotes': '132',
#   'language': 'English Korean',
#   'lastupdated': '22:28.6',
#   'metacritic': '',
#   'plot': "A Korean emigrant's superstitiously suspicious past starts to catch "
#           'up with her as her obsession with her married American neighbors '
#           'begins to twist out of control and off the deep end.',
#   'poster': 'https://m.media-amazon.com/images/M/MV5BMTY0ODExNDc5MF5BMl5BanBnXkFtZTgwMjQyMjA2MDE@._V1_SX300.jpg',
#   'rating': 'NOT RATED',
#   'released': '25-11-2010',
#   'runtime': '87 min',
#   'title': 'Make Yourself at Home',
#   'type': 'movie',
#   'writer': 'Margaret Monaghan Soopum Sohn',
#   'year': '2008'},
#  {'_id': ObjectId('614b7569708918ab1807f3d6'),
#   'awards': '3 nominations.',
#   'cast': 'Young Hun Choi Kang Chol Hwan Lee Shin',
#   'country': 'USA France South Korea',
#   'director': 'N.C. Heikin',
#   'fullplot': 'For some the Korean War was a clear example of American '
#               'imperialism. For others it was a valiant effort on the part of '
#               'the UN and the Koreans to quash the spread of communism. For '
#               'all Koreans it was a tragedy. The country was not just divided; '
#               'it was devastated. The death toll was astronomical and the '
#               'destruction profound. Many engage in assigning blame for the '
#               'war according to their political beliefs but this is a useless '
#               'exercise. The point is that the human rights situation in North '
#               'Korea today is catastrophic. KIMJONGILIA is the first film to '
#               'let North Korean refugees tell their stories in their own '
#               'words.',
#   'genre': 'Documentary Drama',
#   'imdbID': '1180311',
#   'imdbRating': '6.9',
#   'imdbVotes': '683',
#   'language': 'English Korean',
#   'lastupdated': '42:43.2',
#   'metacritic': '44',
#   'plot': 'North Korean defectors tell their stories of repression escape and '
#           'hope.',
#   'poster': 'https://m.media-amazon.com/images/M/MV5BMjA0MDgwMzEwMF5BMl5BanBnXkFtZTcwNDY2MjE5Mw@@._V1_SX300.jpg',
#   'rating': '',
#   'released': '23-06-2011',
#   'runtime': '75 min',
#   'title': 'Kimjongilia',
#   'type': 'movie',
#   'writer': 'N.C. Heikin',
#   'year': '2009'},
#  {'_id': ObjectId('614b756a708918ab1807f5de'),
#   'awards': '2 wins & 4 nominations.',
#   'cast': 'Chris Hemsworth Josh Peck Josh Hutcherson Adrianne Palicki',
#   'country': 'USA',
#   'director': 'Dan Bradley',
#   'fullplot': 'The city of Spokane Washington is awakened by a North Korean '
#               'paratrooper invasion. Marine Corps veteran Jed Eckert and his '
#               'civilian brother Matt escape with a group of friends to an '
#               'isolated cabin in the woods where they witness the execution of '
#               'their father at the hands of the ruthless Captain Cho. The '
#               'brothers unite with their friends to form a guerrilla '
#               'resistance group--the Wolverines--to drive the invaders from '
#               'their home.',
#   'genre': 'Action Thriller War',
#   'imdbID': '1234719',
#   'imdbRating': '5.4',
#   'imdbVotes': '58822',
#   'language': 'English Korean',
#   'lastupdated': '40:16.9',
#   'metacritic': '31',
#   'plot': 'A group of teenagers look to save their town from an invasion of '
#           'North Korean soldiers.',
#   'poster': 'https://m.media-amazon.com/images/M/MV5BMjI0MDAwMzA1M15BMl5BanBnXkFtZTcwNzIxMjY3OA@@._V1_SX300.jpg',
#   'rating': 'PG-13',
#   'released': '21-11-2012',
#   'runtime': '93 min',
#   'title': 'Red Dawn',
#   'type': 'movie',
#   'writer': 'Carl Ellsworth (screenplay) Jeremy Passmore (screenplay) Kevin '
#             'Reynolds John Milius Kevin Reynolds (story)',
#   'year': '2012'},
#  {'_id': ObjectId('614b756a708918ab1807f914'),
#   'awards': '',
#   'cast': '',
#   'country': 'Australia Japan',
#   'director': 'Emma Franz',
#   'fullplot': 'The search for an enigmatic South Korean shaman and the '
#               "inspiration found on the journey renews a jazz musician's faith "
#               'in the power of music.',
#   'genre': 'Documentary Music',
#   'imdbID': '1329371',
#   'imdbRating': '8.6',
#   'imdbVotes': '34',
#   'language': 'English Korean',
#   'lastupdated': '46:53.1',
#   'metacritic': '',
#   'plot': 'The search for an enigmatic South Korean shaman and the inspiration '
#           "found on the journey renews a jazz musician's faith in the power of "
#           'music.',
#   'poster': 'https://m.media-amazon.com/images/M/MV5BODEyODY2NjMwOF5BMl5BanBnXkFtZTgwMTIwMzA2MDE@._V1_SX300.jpg',
#   'rating': '',
#   'released': '02-09-2010',
#   'runtime': '90 min',
#   'title': 'Intangible Asset Number 82',
#   'type': 'movie',
#   'writer': 'Emma Franz',
#   'year': '2008'},
#  {'_id': ObjectId('614b756c708918ab18080403'),
#   'awards': '6 wins & 5 nominations.',
#   'cast': 'Joyce McKinney Peter Tory Troy Williams Jackson Shaw',
#   'country': 'USA',
#   'director': 'Errol Morris',
#   'fullplot': '"Tabloid stories centered on the activities of Joyce McKinney a '
#               'former beauty queen with a self-reported IQ of 168 over her '
#               'life are presented. Beyond her beauty pageant days McKinney '
#               'first hit the tabloid pages in Britain in what was largely '
#               'coined ""The Case of the Manacled Mormon"". As reported by '
#               'McKinney in interviews she a southern Christian originally from '
#               'North Carolina got involved with a group of Mormons in her '
#               'pursuit of true love without knowing they were Mormons or '
#               'anything about Mormonism. She fell in love with one of those '
#               'Mormons Kirk Anderson the two who were to be married. After he '
#               'disappeared without saying anything to her she with the help of '
#               'a private investigator and some male friends and new '
#               'acquaintances tracked him down in England where he was being '
#               'brainwashed by Mormon elders that brainwashing which included '
#               'the notion of sex with and marriage to her a non-Mormon as '
#               'taboo. He left with her voluntarily she who took him away to a '
#               'secluded cottage to do whatever required to get him back to the '
#               'non-brainwashed Kirk she knew which included chaining him down '
#               'to a bed and having sex with him several times over the course '
#               'of a few days. She was eventually charged with kidnapping among '
#               'other charges the case against her led by the Mormon church. '
#               'Tabloid reporters were also involved not so much to uncover the '
#               'truth but dig into other aspects of her life including '
#               'activities which allowed her to fund this mission of finding '
#               'and retrieving Kirk this information which in turn affected the '
#               'case and its reporting. Beyond this case McKinney several years '
#               'later again hit the tabloids with regard to a story about her '
#               'dog Booger which in turn renewed interest in the manacled '
#               'Mormon case. In the end McKinney vows to tell the complete side '
#               'of her story through a book which has become more difficult for '
#               'her to write out of circumstance as time has gone on."',
#   'genre': 'Documentary',
#   'imdbID': '1704619',
#   'imdbRating': '7.1',
#   'imdbVotes': '4658',
#   'language': 'English Korean',
#   'lastupdated': '27:17.9',
#   'metacritic': '74',
#   'plot': 'A documentary on a former Miss Wyoming who is charged with '
#           'abducting and imprisoning a young Mormon Missionary.',
#   'poster': 'https://m.media-amazon.com/images/M/MV5BMTY5ODAwMjcwMl5BMl5BanBnXkFtZTcwMzc5NzA2NQ@@._V1_SX300.jpg',
#   'rating': 'R',
#   'released': '11-11-2011',
#   'runtime': '87 min',
#   'title': 'Tabloid',
#   'type': 'movie',
#   'writer': '',
#   'year': '2010'},
#  {'_id': ObjectId('614b756d708918ab1808079c'),
#   'awards': '',
#   'cast': 'Bridgit Mendler Leigh-Allyn Baker Bradley Steven Perry Mia Talerico',
#   'country': 'USA',
#   'director': 'Arlene Sanford',
#   'fullplot': "Teddy Duncan's middle-class family embarks on a plane flight "
#               "from their Denver home to visit Mrs. Duncan's parents the "
#               'Blankenhoopers in Palm Springs - all except daughter Teddy and '
#               'mother Amy for whom a cross country odyssey begins when a '
#               'chance at free plane fare leads to a curtailed bus ride a '
#               'nightmarish experience in a Yugo hitchhiking with a pair of '
#               'alien abductees and peddling through the desert on a tandem '
#               'bike. All the while the male Duncans survive a zany Christmas '
#               'with Grandpa and Grandma Blankenhooper.',
#   'genre': 'Comedy Drama Family',
#   'imdbID': '1828976',
#   'imdbRating': '6.8',
#   'imdbVotes': '2288',
#   'language': 'English Korean',
#   'lastupdated': '28:00.7',
#   'metacritic': '',
#   'plot': 'Idiocy strikes when a woman and her daughter get separated from '
#           'their family during the holidays.',
#   'poster': 'https://m.media-amazon.com/images/M/MV5BMTk5NTI5NTk0NF5BMl5BanBnXkFtZTgwMTQ1NTA2MDE@._V1_SX300.jpg',
#   'rating': 'TV-G',
#   'released': '02-12-2011',
#   'runtime': '90 min',
#   'title': "Good Luck Charlie It's Christmas!",
#   'type': 'movie',
#   'writer': 'Phil Baker (creator) Drew Vaupen (creator) Geoff Rodkey',
#   'year': '2011'},
#  {'_id': ObjectId('614b756e708918ab1808112c'),
#   'awards': '1 win & 5 nominations.',
#   'cast': 'Gerard Butler Aaron Eckhart Finley Jacobsen Dylan McDermott',
#   'country': 'USA',
#   'director': 'Antoine Fuqua',
#   'fullplot': '"When the White House (Secret Service Code: ""Olympus"") is '
#               'captured by a terrorist mastermind and the President is '
#               'kidnapped disgraced former Presidential Secret Service Agent '
#               'Mike Banning finds himself trapped within the building. As our '
#               'national security team scrambles to respond they are forced to '
#               "rely on Banning's inside knowledge to help retake the White "
#               'House save the President and avert an even bigger disaster."',
#   'genre': 'Action Thriller',
#   'imdbID': '2302755',
#   'imdbRating': '6.5',
#   'imdbVotes': '177080',
#   'language': 'English Korean',
#   'lastupdated': '04:32.1',
#   'metacritic': '41',
#   'plot': 'Disgraced former Presidential guard Mike Banning finds himself '
#           'trapped inside the White House in the wake of a terrorist attack; '
#           'using his inside knowledge Banning works with national security to '
#           'rescue the President from his kidnappers.',
#   'poster': 'https://m.media-amazon.com/images/M/MV5BMTkxNjIyNjE5OF5BMl5BanBnXkFtZTcwMTI3NzkxOQ@@._V1_SX300.jpg',
#   'rating': 'R',
#   'released': '22-03-2013',
#   'runtime': '119 min',
#   'title': 'Olympus Has Fallen',
#   'type': 'movie',
#   'writer': 'Creighton Rothenberger Katrin Benedikt',
#   'year': '2013'},
#  {'_id': ObjectId('614b7571708918ab18081797'),
#   'awards': '1 win & 3 nominations.',
#   'cast': 'James Franco Seth Rogen Lizzy Caplan Randall Park',
#   'country': 'USA',
#   'director': 'Evan Goldberg Seth Rogen',
#   'fullplot': '"In the action-comedy The Interview Dave Skylark (James Franco) '
#               'and his producer Aaron Rapoport (Seth Rogen) run the popular '
#               'celebrity tabloid TV show ""Skylark Tonight."" When they '
#               'discover that North Korean dictator Kim Jong-un is a fan of the '
#               'show they land an interview with him in an attempt to '
#               'legitimize themselves as journalists. As Dave and Aaron prepare '
#               'to travel to Pyongyang their plans change when the CIA recruits '
#               'them perhaps the two least-qualified men imaginable to '
#               'assassinate Kim Jong-un."',
#   'genre': 'Action Comedy',
#   'imdbID': '2788710',
#   'imdbRating': '6.7',
#   'imdbVotes': '217029',
#   'language': 'English Korean',
#   'lastupdated': '02:04.2',
#   'metacritic': '52',
#   'plot': '"Dave Skylark and producer Aaron Rapoport run the celebrity tabloid '
#           'show ""Skylark Tonight."" When they land an interview with a '
#           'surprise fan North Korean dictator Kim Jong-un they are recruited '
#           'by the CIA to turn their trip to Pyongyang into an assassination '
#           'mission."',
#   'poster': 'https://m.media-amazon.com/images/M/MV5BMTQzMTcwMzgyMV5BMl5BanBnXkFtZTgwMzAyMzQ2MzE@._V1_SX300.jpg',
#   'rating': 'R',
#   'released': '24-12-2014',
#   'runtime': '112 min',
#   'title': 'The Interview',
#   'type': 'movie',
#   'writer': 'Dan Sterling (screenplay) Seth Rogen (story) Evan Goldberg '
#             '(story) Dan Sterling (story)',
#   'year': '2014'},
#  {'_id': ObjectId('614b7572708918ab18081f19'),
#   'awards': '',
#   'cast': 'Su-jeong Lim Yeon-Seok Yoo Dean Dawson Dohee',
#   'country': 'South Korea',
#   'director': 'Jae-goo Yoon',
#   'fullplot': 'A young woman is lured by a tempting opportunity that lands her '
#               'in the middle of a power struggle between two men of different '
#               'attributes as they all fight over love and ambition.',
#   'genre': 'Thriller',
#   'imdbID': '3602144',
#   'imdbRating': '6.1',
#   'imdbVotes': '45',
#   'language': 'English Korean',
#   'lastupdated': '36:21.0',
#   'metacritic': '',
#   'plot': 'A young woman is lured by a tempting opportunity that lands her in '
#           'the middle of a power struggle between two men of different '
#           'attributes as they all fight over love and ambition.',
#   'poster': '',
#   'rating': '',
#   'released': '04-06-2015',
#   'runtime': '110 min',
#   'title': 'Eun-mil-han Yu-hok',
#   'type': 'movie',
#   'writer': 'Jae-goo Yoon',
#   'year': '2015'},
#  {'_id': ObjectId('614b7573708918ab18082594'),
#   'awards': '1 win.',
#   'cast': 'Matt Cooper',
#   'country': 'UK North Korea',
#   'director': 'Colin Offland',
#   'fullplot': 'Dennis Rodman is on a mission. After forging an unlikely '
#               'friendship with North Korean leader Kim Jong-un he wants to '
#               'improve relations between North Korea and the US by staging a '
#               'historic basketball game between the two countries. But the '
#               "North Korean team isn't the only opposition he'll face... "
#               'Condemned by the NBA and The Whitehouse and hounded every step '
#               'of the way by the press can Dennis keep it together and make '
#               'the game happen? Or will it go up in a mushroom cloud of smoke? '
#               'For the first time discover the true story of what happened '
#               'when Dennis Rodman took a team of former-NBA players to North '
#               'Korea and staged the most controversial game of basketball the '
#               'world has never seen.',
#   'genre': 'Documentary Sport',
#   'imdbID': '4598848',
#   'imdbRating': '6.4',
#   'imdbVotes': '101',
#   'language': 'English Korean',
#   'lastupdated': '23:29.8',
#   'metacritic': '',
#   'plot': 'Dennis Rodman is on a mission. After forging an unlikely friendship '
#           'with North Korean leader Kim Jong-un he wants to improve relations '
#           'between North Korea and the US by staging a historic ...',
#   'poster': 'https://m.media-amazon.com/images/M/MV5BMTczODAwNjgzNl5BMl5BanBnXkFtZTgwMDU5MTczNTE@._V1_SX300.jpg',
#   'rating': '',
#   'released': '25-01-2015',
#   'runtime': '93 min',
#   'title': "Dennis Rodman's Big Bang in PyongYang",
#   'type': 'movie',
#   'writer': 'Matt Baker Colin Offland (story)',
#   'year': '2015'}]
