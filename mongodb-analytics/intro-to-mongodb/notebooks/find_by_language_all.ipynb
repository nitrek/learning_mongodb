# %%
import pymongo
from pymongo import MongoClient
import pprint
from IPython.display import clear_output
import connect as c
# Replace XXXX with your connection URI from the Atlas UI
client = c.getMongoClient()

filter = {
    'languages': {'$all': ['Korean', 'English']}
}

clear_output()
pprint.pprint(list(client.mflix.movies_scratch.find(filter)))
# Out:
# [{'_id': ObjectId('614b754d708918ab180773b2'),
#   'actors': [''],
#   'awards': '',
#   'countries': ['USA'],
#   'directors': ['Edwin S. Porter'],
#   'fullPlot': 'Panoramic view of the 1901 Pan-American Exposition filmed at '
#               'night. According to Edwin S. Porter this is the first American '
#               'film ever shot at night using incandescent light.',
#   'genres': ['Documentary Short'],
#   'imdb': {'id': '364', 'rating': '5.6', 'votes': '87'},
#   'languages': ['English'],
#   'metacritic': '',
#   'plot': 'A most perfect picture of the Pan-American Exposition buildings '
#           'including the Electric Tower and Temple of Music as they appear at '
#           'night.',
#   'poster': '',
#   'rated': '',
#   'runtime': '1 min',
#   'title': 'Panorama of Esplanade by Night',
#   'type': 'movie',
#   'writers': [''],
#   'year': '1901'},
#  {'_id': ObjectId('614b754d708918ab180773b3'),
#   'actors': ['Thomas White'],
#   'awards': '',
#   'countries': ['USA'],
#   'directors': ['George S. Fleming Edwin S. Porter'],
#   'fullPlot': "Porter's sequential continuity editing links several shots to "
#               'form a narrative of the famous fairy tale story of Jack and his '
#               'magic beanstalk. Borrowing on cinematographic methods '
#               "reminiscent of 'Georges Melies' Porter uses animation double "
#               "exposure and trick photography to illustrate the fairy's "
#               "apparitions Jack's dream and the fast growing beanstalk.",
#   'genres': ['Short Fantasy'],
#   'imdb': {'id': '399', 'rating': '6.2', 'votes': '442'},
#   'languages': ['English'],
#   'metacritic': '',
#   'plot': "Porter's sequential continuity editing links several shots to form "
#           'a narrative of the famous fairy tale story of Jack and his magic '
#           'beanstalk. Borrowing on cinematographic methods ...',
#   'poster': 'https://m.media-amazon.com/images/M/MV5BMjAzNTI3MzI0Nl5BMl5BanBnXkFtZTcwMzQ1MTYzMw@@._V1_SX300.jpg',
#   'rated': '',
#   'runtime': '10 min',
#   'title': 'Jack and the Beanstalk',
#   'type': 'movie',
#   'writers': [''],
#   'year': '1902'},
#  {'_id': ObjectId('614b754d708918ab180773b6'),
#   'actors': ['Vivian Vaughan Arthur White James H. White'],
#   'awards': '',
#   'countries': ['USA'],
#   'directors': ['George S. Fleming Edwin S. Porter'],
#   'fullPlot': "Porter's sequential continuity editing links several shots to "
#               'form a narrative of firemen responding to a house fire. They '
#               'leave the station with their horse drawn pumper arrive on the '
#               'scene and effect the safe rescue of a woman from the burning '
#               'house. But wait she tells them of her child yet asleep in the '
#               'burning bedroom . . .',
#   'genres': ['Short Action'],
#   'imdb': {'id': '447', 'rating': '6.4', 'votes': '1158'},
#   'languages': ['English'],
#   'metacritic': '',
#   'plot': "Porter's sequential continuity editing links several shots to form "
#           'a narrative of firemen responding to a house fire. They leave the '
#           'station with their horse drawn pumper arrive on the ...',
#   'poster': 'https://m.media-amazon.com/images/M/MV5BMjAzNTI3MzI0Nl5BMl5BanBnXkFtZTcwMzQ1MTYzMw@@._V1_SX300.jpg',
#   'rated': 'NOT RATED',
#   'runtime': '6 min',
#   'title': 'Life of an American Fireman',
#   'type': 'movie',
#   'writers': [''],
#   'year': '1903'},
#  {'_id': ObjectId('614b754d708918ab180773b7'),
#   'actors': ["A.C. Abadie Gilbert M. 'Broncho Billy' Anderson George Barnes "
#              'Justus D. Barnes'],
#   'awards': '1 win.',
#   'countries': ['USA'],
#   'directors': ['Edwin S. Porter'],
#   'fullPlot': 'Among the earliest existing films in American cinema - notable '
#               'as the first film that presented a narrative story to tell - it '
#               'depicts a group of cowboy outlaws who hold up a train and rob '
#               "the passengers. They are then pursued by a Sheriff's posse. "
#               'Several scenes have color included - all hand tinted.',
#   'genres': ['Short Western'],
#   'imdb': {'id': '439', 'rating': '7.4', 'votes': '9847'},
#   'languages': ['English'],
#   'metacritic': '',
#   'plot': 'A group of bandits stage a brazen train hold-up only to find a '
#           'determined posse hot on their heels.',
#   'poster': 'https://m.media-amazon.com/images/M/MV5BMTQ4NDE5MDcyNF5BMl5BanBnXkFtZTgwNDU3Njk5MTE@._V1_SX300.jpg',
#   'rated': 'TV-G',
#   'runtime': '11 min',
#   'title': 'The Great Train Robbery',
#   'type': 'movie',
#   'writers': [''],
#   'year': '1903'},
#  {'_id': ObjectId('614b754d708918ab180773be'),
#   'actors': ['Martin Fuller Mrs. William Bechtel Walter Edwin Ethel Jewett'],
#   'awards': '1 win.',
#   'countries': ['USA'],
#   'directors': ['Harold M. Shaw'],
#   'fullPlot': 'Thanks to the Fresh Air Fund a slum child escapes his drunken '
#               "mother for a day's outing in the country. Upon arriving he and "
#               'the other children are told a story about a mythical land of no '
#               "pain. Rather then return to the slum at day's end the lad seeks "
#               'to journey to that beautiful land beyond the sunset.',
#   'genres': ['Short Drama Fantasy'],
#   'imdb': {'id': '488', 'rating': '7.1', 'votes': '448'},
#   'languages': ['English'],
#   'metacritic': '',
#   'plot': 'A young boy opressed by his mother goes on an outing in the country '
#           'with a social welfare group where he dares to dream of a land where '
#           'the cares of his ordinary life fade.',
#   'poster': 'https://m.media-amazon.com/images/M/MV5BMTMzMDcxMjgyNl5BMl5BanBnXkFtZTcwOTgxNjg4Mg@@._V1_SX300.jpg',
#   'rated': 'UNRATED',
#   'runtime': '14 min',
#   'title': 'The Land Beyond the Sunset',
#   'type': 'movie',
#   'writers': ['Dorothy G. Shore'],
#   'year': '1912'},
#  {'_id': ObjectId('614b754d708918ab180773c1'),
#   'actors': [''],
#   'awards': '',
#   'countries': ['UK'],
#   'directors': ['Walter R. Booth'],
#   'fullPlot': 'A magical glowing white motorcar dismembers policemen drives up '
#               'buildings flies through outer space and can transform into a '
#               'horse and carriage. This was a British effort to top Melies at '
#               'his Sci-Fi/fantasy/comedy trick films.',
#   'genres': ['Fantasy Short Comedy'],
#   'imdb': {'id': '534', 'rating': '6.8', 'votes': '467'},
#   'languages': ['English'],
#   'metacritic': '',
#   'plot': 'A British trick film in which a motorist ends up driving around the '
#           'rings of Saturn.',
#   'poster': '',
#   'rated': '',
#   'runtime': '3 min',
#   'title': "The '?' Motorist",
#   'type': 'movie',
#   'writers': [''],
#   'year': '1906'},
#  {'_id': ObjectId('614b754d708918ab180773c2'),
#   'actors': ['Jack Brawn'],
#   'awards': '',
#   'countries': ['USA'],
#   'directors': ['Wallace McCutcheon Edwin S. Porter'],
#   'fullPlot': '"Adapted from Winsor McCay\'s films and comics of the period '
#               'this film follows the established theme: the ""Rarebit Fiend"" '
#               'gorges himself on rarebit and thus suffers spectacular '
#               'hallucinatory dreams."',
#   'genres': ['Short Fantasy'],
#   'imdb': {'id': '546', 'rating': '6.7', 'votes': '1082'},
#   'languages': ['English'],
#   'metacritic': '',
#   'plot': 'The fiend faces the spectacular mind-bending consequences of his '
#           'free-wheeling rarebit binge.',
#   'poster': '',
#   'rated': '',
#   'runtime': '7 min',
#   'title': 'Dream of a Rarebit Fiend',
#   'type': 'movie',
#   'writers': ['Winsor McCay (comic strip)'],
#   'year': '1906'},
#  {'_id': ObjectId('614b754d708918ab180773c8'),
#   'actors': ['Kate Bruce Adele DeGarde Gladys Egan Rose King'],
#   'awards': '',
#   'countries': ['USA'],
#   'directors': ['D.W. Griffith'],
#   'fullPlot': 'In the peaceful valley of Stillwater there is sunshine. All '
#               'nature smiles as we make our way up the lane lined on each side '
#               'with blossoming trees and fragrant flowers until we come upon '
#               "Doctor Harcourt one of God's noblemen seated on the veranda of "
#               'his house with his wife and little daughter Edith. All are '
#               'carefree and happy as we stroll with them through the barley '
#               'fields lanes and daisy beds. It is indeed a beautiful sight a '
#               "trinity of souls each living in the other's being. But the "
#               'fates are jealous and there are gathering clouds to shut out '
#               'the radiance of their happy existence. Little Edith is taken '
#               'very ill and the doctor is at first inclined to think his wife '
#               'is unduly alarmed but upon examining the child he realizes the '
#               'illness to be serious indeed so much so that it would probably '
#               'be fatal for him to leave its side until the crisis is past. '
#               'While so engaged a poor woman of the village hurries to his '
#               'home to enlist his services for her little girl who she fears '
#               'is at the point of death. Oh God! what a situation. His own '
#               'child needing his undivided attention most urgently on the one '
#               'hand and duty on the other. Duty that relentless deity of the '
#               'honorable which so often compels self-sacrifice beckons him on. '
#               'Irresolute for a moment he at length goes assuring his wife '
#               'that be will be but a few minutes away. Arriving at the humble '
#               'cabin of the woman he finds her child very ill indeed requiring '
#               'speedy and unerring attention to save her. Meanwhile Edith his '
#               'own child has grown worse and the mother has dispatched the '
#               'maid to hurry him back home. When the maid arrives and tells '
#               'him the conditions he for a moment wavers but then his duty '
#               "seems clear to him. If he leaves the poor woman's child death "
#               'is inevitable so he dismisses the maid with the word that it '
#               'will be only a few minutes longer and then he will return. '
#               'Little Edith sinks rapidly so the maid is again sent. This time '
#               'he is about to leave as the child is out of danger and will '
#               'recover. So he leaves the poor family happy and relieved to '
#               'rush madly to his own home. What a contrast! There across the '
#               'lifeless form of his dear child lies his moaning '
#               'horror-stricken wife. A slave of duty he yields the life of his '
#               "own dear child to save the life of another's. The valley of "
#               'Stillwater is shrouded in darkness. Such are the temporal deeds '
#               'that will find reward eternal.',
#   'genres': ['Short Drama'],
#   'imdb': {'id': '833', 'rating': '6.6', 'votes': '294'},
#   'languages': ['English'],
#   'metacritic': '',
#   'plot': 'While caring for his sick daughter a doctor is called away to the '
#           'sickbed of a neighbor. He finds the neighbor gravely ill and '
#           "ignores his wife's pleas to come home and care for his own daughter "
#           'who has taken a turn for the worse.',
#   'poster': 'https://m.media-amazon.com/images/M/MV5BNjg3MTI3ODI2N15BMl5BanBnXkFtZTcwMTg1MDA4Mg@@._V1._CR6490235329_SY132_CR2089132_AL_.jpg_V1_SX300.jpg',
#   'rated': 'NOT RATED',
#   'runtime': '14 min',
#   'title': 'The Country Doctor',
#   'type': 'movie',
#   'writers': [''],
#   'year': '1909'},
#  {'_id': ObjectId('614b754d708918ab180773c9'),
#   'actors': ['Frank Powell Grace Henderson James Kirkwood Linda Arvidson'],
#   'awards': '1 win.',
#   'countries': ['USA'],
#   'directors': ['D.W. Griffith'],
#   'fullPlot': 'A greedy tycoon decides on a whim to corner the world market in '
#               "wheat. This doubles the price of bread forcing the grain's "
#               'producers into charity lines and further into poverty. The film '
#               'continues to contrast the ironic differences between the lives '
#               'of those who work to grow the wheat and the life of the man who '
#               'dabbles in its sale for profit.',
#   'genres': ['Short Drama'],
#   'imdb': {'id': '832', 'rating': '6.6', 'votes': '1375'},
#   'languages': ['English'],
#   'metacritic': '',
#   'plot': 'A greedy tycoon decides on a whim to corner the world market in '
#           "wheat. This doubles the price of bread forcing the grain's "
#           'producers into charity lines and further into poverty. The film...',
#   'poster': '',
#   'rated': 'G',
#   'runtime': '14 min',
#   'title': 'A Corner in Wheat',
#   'type': 'movie',
#   'writers': [''],
#   'year': '1909'},
#  {'_id': ObjectId('614b754d708918ab180773ca'),
#   'actors': ['David Miles Marion Leonard Mary Pickford Gladys Egan'],
#   'awards': '',
#   'countries': ['USA'],
#   'directors': ['D.W. Griffith'],
#   'fullPlot': 'A gang of thieves lure a man out of his home so that they can '
#               'rob it and threaten his wife and children. The family barricade '
#               'themselves in an interior room but the criminals are '
#               'well-equipped for breaking in. When the father finds out what '
#               'is happening he must race against time to get back home.',
#   'genres': ['Short Crime Drama'],
#   'imdb': {'id': '942', 'rating': '6.1', 'votes': '446'},
#   'languages': ['English'],
#   'metacritic': '',
#   'plot': 'A gang of thieves lure a man out of his home so that they can rob '
#           'it and threaten his wife and children. The family barricade '
#           'themselves in an interior room but the criminals are ...',
#   'poster': '',
#   'rated': '',
#   'runtime': '8 min',
#   'title': 'The Lonely Villa',
#   'type': 'movie',
#   'writers': ['Charles Foley (novel) Andr� de Lorde (play) Mack Sennett'],
#   'year': '1909'},
#  {'_id': ObjectId('614b754d708918ab180773cb'),
#   'actors': ['Arthur V. Johnson Marion Leonard Henry B. Walthall'],
#   'awards': '',
#   'countries': ['USA'],
#   'directors': ['D.W. Griffith'],
#   'fullPlot': '"In this movie suggested by Poe\'s ""A Cask of Amontillado"" '
#               'The king constructs a cozy windowless love-nest for himself and '
#               'his concubine. However she is not faithful to her sovereign but '
#               "consorts with the court troubadour. In fact they use the king's "
#               'new play chamber for their own lovecraft. When the king '
#               'discovers this he sends for his masons. With the faithless duo '
#               'still inside the masons use stone and mortar to quietly seal '
#               'the only door to the vault..."',
#   'genres': ['Short Drama'],
#   'imdb': {'id': '1032', 'rating': '6.1', 'votes': '428'},
#   'languages': ['English'],
#   'metacritic': '',
#   'plot': 'A king exacts vengeance upon his faithless mistress and her lover.',
#   'poster': '',
#   'rated': '',
#   'runtime': '11 min',
#   'title': 'The Sealed Room',
#   'type': 'movie',
#   'writers': [''],
#   'year': '1909'},
#  {'_id': ObjectId('614b754d708918ab180773cc'),
#   'actors': ['Linda Arvidson John R. Cumpson Flora Finch George Gebhardt'],
#   'awards': '',
#   'countries': ['USA'],
#   'directors': ['D.W. Griffith'],
#   'fullPlot': 'A gentleman with a top hat and a series of women with ever more '
#               'ludicrous hats enter a movie theatre. They refuse to remove '
#               'them until a giant bucket forcibly removes one hat. All but one '
#               'woman then remove their hats and the bucket returns to remove '
#               'the woman.',
#   'genres': ['Comedy Short'],
#   'imdb': {'id': '1062', 'rating': '6.3', 'votes': '626'},
#   'languages': ['English'],
#   'metacritic': '',
#   'plot': 'Set in an early cinema house this comic short illustrates the '
#           "problems with the gals' hats obscuring the movie patron's line of "
#           'vision.',
#   'poster': '',
#   'rated': 'NOT RATED',
#   'runtime': '2 min',
#   'title': 'Those Awful Hats',
#   'type': 'movie',
#   'writers': [''],
#   'year': '1909'},
#  {'_id': ObjectId('614b754d708918ab180773ce'),
#   'actors': ['Mary Fuller Charles Ogle Augustus Phillips'],
#   'awards': '',
#   'countries': ['USA'],
#   'directors': ['J. Searle Dawley'],
#   'fullPlot': 'Frankenstein a young medical student trying to create the '
#               'perfect human being instead creates a misshapen monster. Made '
#               'ill by what he has done Frankenstein is comforted by his '
#               'fianc�e but on his wedding night he is visited by the monster. '
#               'A fight ensues but the monster seeing himself in a mirror is '
#               'horrified and runs away. He later returns entering the new '
#               "bride's room and finds her alone.",
#   'genres': ['Short Fantasy Horror'],
#   'imdb': {'id': '1223', 'rating': '6.5', 'votes': '2149'},
#   'languages': ['English'],
#   'metacritic': '',
#   'plot': 'Frankenstein a young medical student trying to create the perfect '
#           'human being instead creates a misshapen monster. Made ill by what '
#           'he has done Frankenstein is comforted by his fianc�e ...',
#   'poster': 'https://m.media-amazon.com/images/M/MV5BMTg2NjMyMjgxOF5BMl5BanBnXkFtZTgwOTMyNzM2MzE@._V1_SX300.jpg',
#   'rated': 'UNRATED',
#   'runtime': '16 min',
#   'title': 'Frankenstein',
#   'type': 'movie',
#   'writers': ['Mary Shelley (novel) J. Searle Dawley'],
#   'year': '1910'},
#  {'_id': ObjectId('614b754d708918ab180773cf'),
#   'actors': ['Charles West Charles Arling Owen Moore'],
#   'awards': '',
#   'countries': ['USA'],
#   'directors': ['D.W. Griffith'],
#   'fullPlot': 'During the Civil War a father living in a border state leaves '
#               'to join the Union Army. After he leaves Confederate troops '
#               'forage on his property where a soldier encounters one of his '
#               'daughters. The father himself is wounded on a hazardous mission '
#               'and must run for his life pursued by Confederate soldiers.',
#   'genres': ['Short Drama War'],
#   'imdb': {'id': '1265', 'rating': '6.5', 'votes': '331'},
#   'languages': ['English'],
#   'metacritic': '',
#   'plot': 'During the Civil War a father living in a border state leaves to '
#           'join the Union Army. After he leaves Confederate troops forage on '
#           'his property where a soldier encounters one of his ...',
#   'poster': '',
#   'rated': 'NOT RATED',
#   'runtime': '17 min',
#   'title': 'In the Border States',
#   'type': 'movie',
#   'writers': [''],
#   'year': '1910'},
#  {'_id': ObjectId('614b754d708918ab180773d0'),
#   'actors': ['Arthur V. Johnson Linda Arvidson Gladys Egan Mary Pickford'],
#   'awards': '',
#   'countries': ['USA'],
#   'directors': ['D.W. Griffith'],
#   'fullPlot': 'In this story set at a seaside fishing village and inspired by '
#               "a Charles Kingsley poem a young couple's happy life is turned "
#               'about by an accident. The husband although saved from drowning '
#               'loses his memory. A child is on the way and soon a daughter is '
#               'born to his wife. We watch the passage of time as his daughter '
#               'matures and his wife ages. The daughter becomes a lovely young '
#               'woman herself ready for marriage. One day on the beach the '
#               'familiarity of the sea and the surroundings triggers a return '
#               "of her father's memory and we are reminded that although people "
#               'age and change the sea and the ways of the fisherfolk remain '
#               'eternal.',
#   'genres': ['Drama Short'],
#   'imdb': {'id': '1431', 'rating': '6.5', 'votes': '343'},
#   'languages': ['English'],
#   'metacritic': '',
#   'plot': 'In this story set at a seaside fishing village and inspired by a '
#           "Charles Kingsley poem a young couple's happy life is turned about "
#           'by an accident. The husband although saved from drowning...',
#   'poster': '',
#   'rated': '',
#   'runtime': '14 min',
#   'title': 'The Unchanging Sea',
#   'type': 'movie',
#   'writers': ['Charles Kingsley (poem)'],
#   'year': '1910'},
#  {'_id': ObjectId('614b754d708918ab180773d1'),
#   'actors': ['Bebe Daniels Hobart Bosworth Eugenie Besserer Robert Z. Leonard'],
#   'awards': '',
#   'countries': ['USA'],
#   'directors': ['Otis Turner'],
#   'fullPlot': 'Chased off by the antics of Hank the Mule Dorothy ends up in '
#               "her cornfield where she realizes her family's Scarecrow is "
#               'alive. She helps him down and he takes a tumble on the '
#               'turnstyle. A cyclone soon arrives and leaves Dorothy Scarecrow '
#               'Toto and Hank spinning around on a haystack with Imogene the '
#               'Cow flying soon after. Soon after their arrival the Wizard of '
#               'Oz issues a public decree that he is a humbug to make sure no '
#               'one ever finds out. Glinda pops up out of the background and '
#               'transforms Toto into a man in a bulldog suit to serve as a '
#               'better protector for Dorothy. Then they encounter the Tin '
#               'Woodman the Cowardly Lion and Eureka. Nevertheless she is '
#               'captured by Momba the Wicked Witch of the West (suggesting Baum '
#               'thought the other witches were Mombe Mombo and Mombu in keeping '
#               'with the council in _Queen Zixi of Ix_) and her flying lizards '
#               'and soldiers. Dorothy defeats Momba and they arrive at the '
#               "Emerald City just in time for the Wizard's going away party.",
#   'genres': ['Adventure Fantasy Short'],
#   'imdb': {'id': '1463', 'rating': '5.7', 'votes': '1030'},
#   'languages': ['English'],
#   'metacritic': '',
#   'plot': 'An early version of the classic based more on the 1902 stage '
#           'musical than on the original novel.',
#   'poster': '',
#   'rated': 'NOT RATED',
#   'runtime': '13 min',
#   'title': 'The Wonderful Wizard of Oz',
#   'type': 'movie',
#   'writers': ['L. Frank Baum (novel) Otis Turner (scenario)'],
#   'year': '1910'},
#  {'_id': ObjectId('614b754d708918ab180773d3'),
#   'actors': ['John Bunny Flora Finch Helene Costello Kate Price'],
#   'awards': '',
#   'countries': ['USA'],
#   'directors': ['Laurence Trimble'],
#   'fullPlot': 'A widower has been bringing up his young daughter with the help '
#               "of a nurse. The widower's sister though considers the child to "
#               'be spoiled and undisciplined so she insists on hiring a strict '
#               'governess for the girl. When the governess arrives both the '
#               'daughter and the nurse dislike her but the father is captivated '
#               "by the governess's long wavy chestnut-colored hair. When the "
#               'father asks the governess to marry him the nurse and the '
#               'daughter realize that they have to act quickly.',
#   'genres': ['Comedy Short'],
#   'imdb': {'id': '1660', 'rating': '5.7', 'votes': '135'},
#   'languages': ['English'],
#   'metacritic': '',
#   'plot': "A widower becomes infatuated with his daughter's governess to the "
#           'displeasure of the child and her nurse.',
#   'poster': '',
#   'rated': 'UNRATED',
#   'runtime': '14 min',
#   'title': 'Her Crowning Glory',
#   'type': 'movie',
#   'writers': [''],
#   'year': '1911'},
#  {'_id': ObjectId('614b754d708918ab180773d4'),
#   'actors': ['Blanche Sweet Francis J. Grandon Wilfred Lucas Edward Dillon'],
#   'awards': '',
#   'countries': ['USA'],
#   'directors': ['D.W. Griffith'],
#   'fullPlot': 'When her father becomes ill a young woman takes over the '
#               'telegraph at a lonely western railroad station. She soon gets '
#               'word that the next train will deliver the payroll for a mining '
#               'company. The train brings not only the money but a pair of '
#               'ruffians bent on stealing it. All alone she wires for help and '
#               'then holds off the bad guys until it arrives.',
#   'genres': ['Short Drama Romance'],
#   'imdb': {'id': '1740', 'rating': '6.6', 'votes': '662'},
#   'languages': ['English'],
#   'metacritic': '',
#   'plot': 'When her father becomes ill a young woman takes over the telegraph '
#           'at a lonely western railroad station. She soon gets word that the '
#           'next train will deliver the payroll for a mining ...',
#   'poster': '',
#   'rated': 'UNRATED',
#   'runtime': '17 min',
#   'title': 'The Lonedale Operator',
#   'type': 'movie',
#   'writers': [''],
#   'year': '1911'},
#  {'_id': ObjectId('614b754d708918ab180773d5'),
#   'actors': ['Winsor McCay'],
#   'awards': '1 win.',
#   'countries': ['USA'],
#   'directors': ['Winsor McCay J. Stuart Blackton'],
#   'fullPlot': 'Cartoonist Winsor McCay agrees to create a large set of '
#               'drawings that will be photographed and made into a motion '
#               'picture. The job requires plenty of drawing supplies and the '
#               'cartoonist must also overcome some mishaps caused by an '
#               'assistant. Finally the work is done and everyone can see the '
#               'resulting animated picture.',
#   'genres': ['Animation Short Comedy'],
#   'imdb': {'id': '1737', 'rating': '7.3', 'votes': '1034'},
#   'languages': ['English'],
#   'metacritic': '',
#   'plot': 'Cartoon figures announce via comic strip balloons that they will '
#           'move - and move they do in a wildly exaggerated style.',
#   'poster': 'https://m.media-amazon.com/images/M/MV5BMTU5MTk0NDM5N15BMl5BanBnXkFtZTcwMDAyOTYxMQ@@._V1_SX300.jpg',
#   'rated': '',
#   'runtime': '7 min',
#   'title': 'Winsor McCay the Famous Cartoonist of the N.Y. Herald and His '
#            'Moving Comics',
#   'type': 'movie',
#   'writers': ['"Winsor McCay (comic strip ""Little Nemo in Slumberland"") '
#               'Winsor McCay (screenplay)"'],
#   'year': '1911'},
#  {'_id': ObjectId('614b754d708918ab180773d6'),
#   'actors': ['Linda Arvidson Lionel Barrymore William J. Butler Donald Crisp'],
#   'awards': '',
#   'countries': ['USA'],
#   'directors': ['D.W. Griffith'],
#   'fullPlot': 'Kathy a young child has befriended the elderly miser who lives '
#               'on an upper floor of the building where she lives. Today while '
#               'playing outside she also makes friends with Jules a homeless '
#               "petty thief. Later when she is in the miser's apartment two "
#               'violent criminals break in. They tie a rope around Kathy and '
#               'dangle her out of a window threatening to let her fall to the '
#               'ground if the miser does not give them the combination to his '
#               'safe. Outside Jules sees her in danger but to help her he must '
#               'risk dealing with the police.',
#   'genres': ['Short Crime Drama'],
#   'imdb': {'id': '1789', 'rating': '6.4', 'votes': '149'},
#   'languages': ['English'],
#   'metacritic': '',
#   'plot': 'Thieves decide to steal the money an old miser has hidden away. He '
#           'refuses to open the safe for them so they threaten to kill a girl '
#           'who lives in his building.',
#   'poster': '',
#   'rated': '',
#   'runtime': '18 min',
#   'title': "The Miser's Heart",
#   'type': 'movie',
#   'writers': ['George Hennessy'],
#   'year': '1911'},
#  {'_id': ObjectId('614b754d708918ab180773d7'),
#   'actors': ['Mary Pickford Edwin August Alfred Paget Mae Marsh'],
#   'awards': '',
#   'countries': ['USA'],
#   'directors': ['D.W. Griffith'],
#   'fullPlot': 'A young and fickle girl ( Mary Pickford ) dumps her admiring '
#               'boyfriend ( Edwin August ) because she views him as a coward. '
#               'Meanwhile a ruthless convict ( Alfred Paget ) has escaped and '
#               'takes the girl as his hostage. After a harrowing automobile and '
#               'train chase the ex-boyfriend rescues the girl and he '
#               'immediately becomes her hero which she seals with a kiss.',
#   'genres': ['Short Drama'],
#   'imdb': {'id': '2054', 'rating': '5.6', 'votes': '75'},
#   'languages': ['English'],
#   'metacritic': '',
#   'plot': 'A young and fickle girl ( Mary Pickford ) dumps her admiring '
#           'boyfriend ( Edwin August ) because she views him as a coward. '
#           'Meanwhile a ruthless convict ( Alfred Paget ) has escaped and ...',
#   'poster': '',
#   'rated': '',
#   'runtime': '17 min',
#   'title': 'A Beast at Bay',
#   'type': 'movie',
#   'writers': ['George Hennessy'],
#   'year': '1912'},
#  {'_id': ObjectId('614b754d708918ab180773d8'),
#   'actors': ['Helen Gardner Pearl Sindelar Miss Fielding Miss Robson'],
#   'awards': '',
#   'countries': ['USA'],
#   'directors': ['Charles L. Gaskill'],
#   'fullPlot': '"When she discovers that a slave named Pharon professes his '
#               'love for her Cleopatra makes a bargain with him: she will give '
#               'him ten days of ""love"" at the end of which he is to commit '
#               "suicide. He agrees although the queen's handmaiden Iras in love "
#               "with the slave isn't happy with the arrangement. Later when "
#               'Cleopatra is seducing Marc Antony her relationship with Pharon '
#               'is used against her but with little effect. She allies herself '
#               'with Antony against Octavius participates in a brief war then '
#               'meets her end rather than be subjected to Roman rule."',
#   'genres': ['Drama History'],
#   'imdb': {'id': '2101', 'rating': '5.1', 'votes': '291'},
#   'languages': ['English'],
#   'metacritic': '',
#   'plot': "The fabled queen of Egypt's affair with Roman general Marc Antony "
#           'is ulimately disastrous for both of them.',
#   'poster': '',
#   'rated': 'UNRATED',
#   'runtime': '88 min',
#   'title': 'Cleopatra',
#   'type': 'movie',
#   'writers': ['Victorien Sardou (adapted from the play by)'],
#   'year': '1912'},
#  {'_id': ObjectId('614b754d708918ab180773da'),
#   'actors': ['Lionel Barrymore Henry B. Walthall Robert Harron Harry Carey'],
#   'awards': '',
#   'countries': ['USA'],
#   'directors': ['D.W. Griffith'],
#   'fullPlot': 'In this latter day Cain and Abel story a jealous brother '
#               'strikes down his sibling just as a young burglar is about to '
#               'enter the house. The jealous brother summons police who then '
#               'charge the young intruder with murder. How can the burglar '
#               'prove his innocence?',
#   'genres': ['Short Drama'],
#   'imdb': {'id': '2082', 'rating': '6.1', 'votes': '210'},
#   'languages': ['English'],
#   'metacritic': '',
#   'plot': 'In this latter day Cain and Abel story a jealous brother strikes '
#           'down his sibling just as a young burglar is about to enter the '
#           'house. The jealous brother summons police who then charge ...',
#   'poster': '',
#   'rated': '',
#   'runtime': '15 min',
#   'title': "The Burglar's Dilemma",
#   'type': 'movie',
#   'writers': ['Lionel Barrymore'],
#   'year': '1912'},
#  {'_id': ObjectId('614b754d708918ab180773dc'),
#   'actors': ['Mary Pickford Charles West Mabel Normand Charles Hill Mailes'],
#   'awards': '',
#   'countries': ['USA'],
#   'directors': ['D.W. Griffith'],
#   'fullPlot': "A young woman who works mending fishermen's nets is engaged to "
#               'be married. But her fianc� has an old love who refuses to let '
#               'him go. Further his former girlfriend has a brother who is '
#               "willing to use violence to protect his sister's honor.",
#   'genres': ['Short Romance'],
#   'imdb': {'id': '2357', 'rating': '6.1', 'votes': '103'},
#   'languages': ['English'],
#   'metacritic': '',
#   'plot': "A young woman who works mending fishermen's nets is engaged to be "
#           'married. But her fianc� has an old love who refuses to let him go. '
#           'Further his former girlfriend has a brother who is ...',
#   'poster': '',
#   'rated': '',
#   'runtime': '16 min',
#   'title': 'The Mender of Nets',
#   'type': 'movie',
#   'writers': [''],
#   'year': '1912'},
#  {'_id': ObjectId('614b754d708918ab180773dd'),
#   'actors': ['Elmer Booth Lillian Gish Clara T. Bracy Walter Miller'],
#   'awards': '',
#   'countries': ['USA'],
#   'directors': ['D.W. Griffith'],
#   'fullPlot': 'A young wife and her musician husband live in poverty in a New '
#               "York City tenement. The husband's job requires him to go away "
#               'for for a number of days. On his return he is robbed by the '
#               'neighborhood gangster. Sometime later an unrelated mob '
#               'shoot-out ensues. The husband happens upon the melee '
#               'recognizing the crook who robbed him. Can the husband retrieve '
#               'his money?',
#   'genres': ['Short Crime Drama'],
#   'imdb': {'id': '2381', 'rating': '6.7', 'votes': '1226'},
#   'languages': ['English'],
#   'metacritic': '',
#   'plot': 'A young wife and her musician husband live in poverty in a New York '
#           "City tenement. The husband's job requires him to go away for for a "
#           'number of days. On his return he is robbed by the ...',
#   'poster': 'https://m.media-amazon.com/images/M/MV5BMTkyNzk5MDYzOV5BMl5BanBnXkFtZTgwNzQ3Njk5MTE@._V1_SX300.jpg',
#   'rated': '',
#   'runtime': '17 min',
#   'title': 'The Musketeers of Pig Alley',
#   'type': 'movie',
#   'writers': [''],
#   'year': '1912'},
#  {'_id': ObjectId('614b754d708918ab180773de'),
#   'actors': ['Mary Pickford Charles Hill Mailes Kate Bruce Lionel Barrymore'],
#   'awards': '',
#   'countries': ['USA'],
#   'directors': ['D.W. Griffith'],
#   'fullPlot': 'When Mrs. Harding dies she leaves a mysterious letter to her '
#               'pastor. The note tells how her cold miserly husband worked her '
#               'to death. She asks the pastor to administer a small trust which '
#               'she has bequeathed her daughter so that the girl might enjoy '
#               'some finery which her father has always denied her. The village '
#               'milliner carries the latest hat styles from New York one of '
#               "which has caught the girl's fancy. The pastor loyal to the "
#               "dying mother's wishes buys the young lady the hat. Soon gossip "
#               'spreads through the village...',
#   'genres': ['Short Drama'],
#   'imdb': {'id': '2391', 'rating': '6.5', 'votes': '468'},
#   'languages': ['English'],
#   'metacritic': '',
#   'plot': 'When Mrs. Harding dies she leaves a mysterious letter to her '
#           'pastor. The note tells how her cold miserly husband worked her to '
#           'death. She asks the pastor to administer a small trust which...',
#   'poster': 'https://m.media-amazon.com/images/M/MV5BMTgzNDIwMzM3MV5BMl5BanBnXkFtZTcwOTAxOTAyMQ@@._V1_SX300.jpg',
#   'rated': '',
#   'runtime': '16 min',
#   'title': 'The New York Hat',
#   'type': 'movie',
#   'writers': ['Anita Loos Frances Marion (contributing writer)'],
#   'year': '1912'},
#  {'_id': ObjectId('614b754d708918ab180773df'),
#   'actors': ['Blanche Sweet Madge Kirby Charles Hill Mailes Kate Bruce'],
#   'awards': '',
#   'countries': ['USA'],
#   'directors': ['D.W. Griffith'],
#   'fullPlot': 'A lonely young woman lives with her strict father who forbids '
#               'her to wear make-up. One day at an ice cream social she meets a '
#               'young man you seems interested in her. However unknown to her '
#               'he is a burglar who is only interested in breaking into her '
#               "father's house. One night she is awakened by a noise. Grabbing "
#               "a pistol she enters her father's downstairs office where she "
#               'confronts a masked intruder . . .',
#   'genres': ['Short Drama'],
#   'imdb': {'id': '2415', 'rating': '6', 'votes': '306'},
#   'languages': ['English'],
#   'metacritic': '',
#   'plot': 'A lonely young woman lives with her strict father who forbids her '
#           'to wear make-up. One day at an ice cream social she meets a young '
#           'man you seems interested in her. However unknown to her...',
#   'poster': '',
#   'rated': '',
#   'runtime': '12 min',
#   'title': 'The Painted Lady',
#   'type': 'movie',
#   'writers': [''],
#   'year': '1912'},
#  {'_id': ObjectId('614b754d708918ab180773e0'),
#   'actors': ['Robert Gemp Frederick Warde Albert Gardner James Keane'],
#   'awards': '',
#   'countries': ['France USA'],
#   'directors': ['Andr� Calmettes James Keane'],
#   'fullPlot': "Shakespeare's tragedy of the hump-backed Duke of Gloucester who "
#               'rises to the throne of England by chicanery treachery and '
#               'brilliance only to find that his own methods have prepared the '
#               'groundwork for his downfall.',
#   'genres': ['Drama'],
#   'imdb': {'id': '2461', 'rating': '5.6', 'votes': '173'},
#   'languages': ['English'],
#   'metacritic': '',
#   'plot': 'Richard of Gloucester uses manipulation and murder to gain the '
#           'English throne.',
#   'poster': 'https://m.media-amazon.com/images/M/MV5BMTQ1ODY2NTU4OF5BMl5BanBnXkFtZTgwNTc3NjU4MDE@._V1_SX300.jpg',
#   'rated': '',
#   'runtime': '55 min',
#   'title': 'The Life and Death of King Richard III',
#   'type': 'movie',
#   'writers': ['James Keane William Shakespeare (play)'],
#   'year': '1912'},
#  {'_id': ObjectId('614b754d708918ab180773e2'),
#   'actors': ['Blanche Sweet Henry B. Walthall Walter Miller Lionel Barrymore'],
#   'awards': '',
#   'countries': ['USA'],
#   'directors': ['D.W. Griffith'],
#   'fullPlot': 'Two business partners pursue the same woman. She accepts the '
#               'marriage proposal of the irresponsible partner much to her '
#               'later regret. He squanders money on gambling as his interest in '
#               'her gradually wanes. One day after losing the company money in '
#               'a card game he decides to commit suicide. He telephones his '
#               'wife from the office as he puts a revolver near his head. The '
#               'wife tries to keep him talking while the reliable business '
#               'partner races to the office in an attempt to save his old '
#               'friend. Will he make it in time?',
#   'genres': ['Short Drama Romance'],
#   'imdb': {'id': '2795', 'rating': '6.2', 'votes': '336'},
#   'languages': ['English'],
#   'metacritic': '',
#   'plot': 'Two business partners pursue the same woman. She accepts the '
#           'marriage proposal of the irresponsible partner much to her later '
#           'regret. He squanders money on gambling as his interest in her...',
#   'poster': '',
#   'rated': '',
#   'runtime': '17 min',
#   'title': "Death's Marathon",
#   'type': 'movie',
#   'writers': ['William E. Wing'],
#   'year': '1913'},
#  {'_id': ObjectId('614b754d708918ab180773e4'),
#   'actors': ['Lionel Barrymore Claire McDowell Charles Hill Mailes Lillian '
#              'Gish'],
#   'awards': '',
#   'countries': ['USA'],
#   'directors': ['D.W. Griffith'],
#   'fullPlot': 'A potentially violent patient in an insane asylum is calmed '
#               'when he hears a nurse playing the piano. But shortly afterwards '
#               'he breaks free eludes his pursuers and acquires a gun. He soon '
#               'comes to a house where a young wife is home alone and there is '
#               'a tense confrontation.',
#   'genres': ['Short Drama'],
#   'imdb': {'id': '2985', 'rating': '6.1', 'votes': '175'},
#   'languages': ['English'],
#   'metacritic': '',
#   'plot': 'A potentially violent patient in an insane asylum is calmed when he '
#           'hears a nurse playing the piano. But shortly afterwards he breaks '
#           'free eludes his pursuers and acquires a gun. He soon ...',
#   'poster': '',
#   'rated': '',
#   'runtime': '17 min',
#   'title': 'The House of Darkness',
#   'type': 'movie',
#   'writers': ['Jere F. Looney'],
#   'year': '1913'},
#  {'_id': ObjectId('614b754d708918ab180773e6'),
#   'actors': ['Edwin Carewe Jean Thomas Virginia Mann Ninita Bristow'],
#   'awards': '',
#   'countries': ['USA'],
#   'directors': ['Frank Beal'],
#   'fullPlot': 'A dramatization of the methods in which young women are '
#               'abducted or otherwise procured for prostitution.',
#   'genres': ['Short Drama'],
#   'imdb': {'id': '3016', 'rating': '5.7', 'votes': '37'},
#   'languages': ['English'],
#   'metacritic': '',
#   'plot': 'A dramatization of the methods in which young women are abducted or '
#           'otherwise procured for prostitution.',
#   'poster': 'https://m.media-amazon.com/images/M/MV5BNTk1MDkxNDkzNF5BMl5BanBnXkFtZTcwNzg1NzA5Nw@@._V1_SX300.jpg',
#   'rated': '',
#   'runtime': '28 min',
#   'title': 'The Inside of the White Slave Traffic',
#   'type': 'movie',
#   'writers': ['Frank Beal (story) Samuel H. London (story)'],
#   'year': '1913'},
#  {'_id': ObjectId('614b754d708918ab180773ea'),
#   'actors': ['Jane Gail Ethel Grandin William H. Turner Matt Moore'],
#   'awards': '1 win.',
#   'countries': ['USA'],
#   'directors': ['George Loane Tucker'],
#   'fullPlot': '',
#   'genres': ['Crime Drama'],
#   'imdb': {'id': '3471', 'rating': '6', 'votes': '371'},
#   'languages': ['English'],
#   'metacritic': '',
#   'plot': 'A woman with the aid of her police officer sweetheart endeavors to '
#           'uncover the prostitution ring that has kidnapped her sister and the '
#           'philanthropist who secretly runs it.',
#   'poster': 'https://m.media-amazon.com/images/M/MV5BMTU2NDg2ODkxMV5BMl5BanBnXkFtZTcwOTQzNzAzMg@@._V1_SX300.jpg',
#   'rated': 'TV-PG',
#   'runtime': '88 min',
#   'title': 'Traffic in Souls',
#   'type': 'movie',
#   'writers': [''],
#   'year': '1913'},
#  {'_id': ObjectId('614b754d708918ab180773ec'),
#   'actors': ['Henry B. Walthall Spottiswoode Aitken Blanche Sweet George '
#              'Siegmann'],
#   'awards': '',
#   'countries': ['USA'],
#   'directors': ['D.W. Griffith'],
#   'fullPlot': 'Thwarted by his despotic uncle from continuing his love affair '
#               'a young man turns to thoughts of murder. Experiencing a series '
#               'of visions he sees murder as a normal course of events in life '
#               'and kills his uncle. Tortured by his conscience his future '
#               'sanity is uncertain as he is assailed by nightmarish visions of '
#               'what he has done.',
#   'genres': ['Crime Drama'],
#   'imdb': {'id': '3643', 'rating': '7', 'votes': '788'},
#   'languages': ['English'],
#   'metacritic': '',
#   'plot': 'Objected to date his sweetheart by his uncle a young man turns his '
#           'thoughts to murder.',
#   'poster': 'https://m.media-amazon.com/images/M/MV5BNDQwOTk3MDExOV5BMl5BanBnXkFtZTgwNDY1MTEwMjE@._V1_SX300.jpg',
#   'rated': 'NOT RATED',
#   'runtime': '78 min',
#   'title': "The Avenging Conscience: or 'Thou Shalt Not Kill'",
#   'type': 'movie',
#   'writers': ['Edgar Allan Poe (stories) D.W. Griffith'],
#   'year': '1914'},
#  {'_id': ObjectId('614b754d708918ab180773ed'),
#   'actors': ['Mae Marsh Leslie Loveridge Alfred Paget Robert Harron'],
#   'awards': '',
#   'countries': ['USA'],
#   'directors': ['D.W. Griffith'],
#   'fullPlot': '',
#   'genres': ['Short Action Western'],
#   'imdb': {'id': '3662', 'rating': '6.4', 'votes': '485'},
#   'languages': ['English'],
#   'metacritic': '',
#   'plot': '',
#   'poster': 'https://m.media-amazon.com/images/M/MV5BMTcwMDU0OTk3NV5BMl5BanBnXkFtZTgwNTU4NjU4MDE@._V1_SX300.jpg',
#   'rated': '',
#   'runtime': '29 min',
#   'title': 'The Battle at Elderbush Gulch',
#   'type': 'movie',
#   'writers': ['D.W. Griffith Henry Albert Phillips'],
#   'year': '1913'},
#  {'_id': ObjectId('614b754e708918ab180773ef'),
#   'actors': ['Mary Pickford Owen Moore Isabel Vernon Georgia Wilson'],
#   'awards': '',
#   'countries': ['USA'],
#   'directors': ['James Kirkwood'],
#   'fullPlot': 'Based on the fairy tale: Cinderella is mistreated by her '
#               'stepmother and stepsisters and is forced to live as their '
#               'servant. One day the Fairy Godmother appears to the family '
#               'disguised as an elderly destitute woman. The others treat her '
#               'harshly but Cinderella is kind to her and feeds her. The Fairy '
#               'Godmother invisibly helps Cinderella helping her when she goes '
#               'to gather wood and enabling her to meet Prince Charming as he '
#               'travels through the forest. Soon afterward the king plans a '
#               'great ball so that the prince can meet all the women and choose '
#               'one for his bride. Cinderella must help her family prepare for '
#               'the ball while she stays at home. But the Fairy Godmother '
#               'appears again and miraculously enables Cinderella to go after '
#               'all with dramatic consequences.',
#   'genres': ['Fantasy Drama'],
#   'imdb': {'id': '3772', 'rating': '6.9', 'votes': '753'},
#   'languages': ['English'],
#   'metacritic': '',
#   'plot': 'Based on the fairy tale: Cinderella is mistreated by her stepmother '
#           'and stepsisters but is able to go to the royal ball through the '
#           'help of the Fairy Godmother.',
#   'poster': 'https://m.media-amazon.com/images/M/MV5BMTcxODcyNjAwN15BMl5BanBnXkFtZTcwMTc1MzI1Mw@@._V1_SX300.jpg',
#   'rated': '',
#   'runtime': '52 min',
#   'title': 'Cinderella',
#   'type': 'movie',
#   'writers': ['Charles Perrault (story)'],
#   'year': '1914'},
#  {'_id': ObjectId('614b754e708918ab180773f2'),
#   'actors': ['Winsor McCay George McManus Roy L. McCardell'],
#   'awards': '1 win.',
#   'countries': ['USA'],
#   'directors': ['Winsor McCay'],
#   'fullPlot': 'Winsor Z. McCay bets another cartoonist that he can animate a '
#               'dinosaur. So he draws a big friendly herbivore called Gertie. '
#               'Then he get into his own picture. Gertie walks through the '
#               'picture eats a tree meets her creator and takes him carefully '
#               'on her back for a ride.',
#   'genres': ['Animation Short Comedy'],
#   'imdb': {'id': '4008', 'rating': '7.3', 'votes': '1837'},
#   'languages': ['English'],
#   'metacritic': '',
#   'plot': 'The cartoonist Winsor McCay brings the Dinosaurus back to life in '
#           'the figure of his latest creation Gertie the Dinosaur.',
#   'poster': 'https://m.media-amazon.com/images/M/MV5BMTQxNzI4ODQ3NF5BMl5BanBnXkFtZTgwNzY5NzMwMjE@._V1_SX300.jpg',
#   'rated': '',
#   'runtime': '12 min',
#   'title': 'Gertie the Dinosaur',
#   'type': 'movie',
#   'writers': ['Winsor McCay'],
#   'year': '1914'},
#  {'_id': ObjectId('614b754e708918ab180773f4'),
#   'actors': ['Charles Chaplin Mack Swain Fritz Schade Cecile Arnold'],
#   'awards': '',
#   'countries': ['USA'],
#   'directors': ['Charles Chaplin'],
#   'fullPlot': '"Charlie and his partner are to deliver a piano to 666 Prospect '
#               'St. and repossess one from 999 Prospect St. They confuse the '
#               'addresses. The difficulties of delivering the piano by mule '
#               'cart and most of the specific gags appeared later in Laurel and '
#               'Hardy\'s ""The Music Box""."',
#   'genres': ['Short Comedy'],
#   'imdb': {'id': '4100', 'rating': '6', 'votes': '483'},
#   'languages': ['English'],
#   'metacritic': '',
#   'plot': 'Charlie and his partner are to deliver a piano to 666 Prospect St. '
#           'and repossess one from 999 Prospect St. They confuse the addresses. '
#           'The difficulties of delivering the piano by mule cart...',
#   'poster': 'https://m.media-amazon.com/images/M/MV5BOTE1MjM3NjI1N15BMl5BanBnXkFtZTgwODc5NDcwNDE@._V1_SX300.jpg',
#   'rated': '',
#   'runtime': '16 min',
#   'title': 'His Musical Career',
#   'type': 'movie',
#   'writers': [''],
#   'year': '1914'},
#  {'_id': ObjectId('614b754e708918ab180773f5'),
#   'actors': ['Charles Chaplin Charley Chase Peggy Page Jess Dandy'],
#   'awards': '',
#   'countries': ['USA'],
#   'directors': ['Charles Chaplin'],
#   'fullPlot': '"Charlie meets a couple and agrees to care for the man\'s '
#               "crippled uncle. After the couple breaks up the man's new girl "
#               'drops some eggs which Charlie slips on while trying to control '
#               'the wheelchair. Charlie sets up the uncle near another '
#               "wheelchair on a jetty from which he lifts a beggar's cup and "
#               '""invalid"" sign. These he places with the uncle and money '
#               'begins to roll in. Charlie takes the money and buys himself a '
#               'drink. Returning he gets to know the abandoned young woman. '
#               'After pushing the uncle and his chair into the drink and '
#               'battling the beggar and two policemen (one of whom arrests the '
#               'uncle) Charlie beats up his rival and gets the girl."',
#   'genres': ['Short Comedy'],
#   'imdb': {'id': '4101', 'rating': '6.1', 'votes': '673'},
#   'languages': ['English'],
#   'metacritic': '',
#   'plot': "Charlie meets a couple and agrees to care for the man's crippled "
#           "uncle. After the couple breaks up the man's new girl drops some "
#           'eggs which Charlie slips on while trying to control the ...',
# ...
#   'writers': [''],
#   'year': '1914'},
#  {'_id': ObjectId('614b754e708918ab180773f6'),
#   'actors': ['Courtenay Foote Myrtle Stedman Herbert Standing Adele '
#              'Farrington'],
#   'awards': '',
#   'countries': ['USA'],
#   'directors': ['Lois Weber'],
#   'fullPlot': 'The parallel stories of a modern preacher and a medieval monk '
#               'Gabriel the Ascetic who is killed by an ignorant mob for making '
#               'a nude statue representing Truth which is also represented by a '
#               'ghostly naked girl who flits throughout the film.',
#   'genres': ['Drama'],
#   'imdb': {'id': '4134', 'rating': '5.9', 'votes': '257'},
#   'languages': ['English'],
#   'metacritic': '',
#   'plot': 'The parallel stories of a modern preacher and a medieval monk '
#           'Gabriel the Ascetic who is killed by an ignorant mob for making a '
#           'nude statue representing Truth which is also represented by a '
#           'ghostly naked girl who flits throughout the film.',
#   'poster': 'https://m.media-amazon.com/images/M/MV5BMjA5NTYzNDQ4NV5BMl5BanBnXkFtZTgwMzA5NzgwMzE@._V1._CR192425407_SY132_CR24089132_AL_.jpg_V1_SX300.jpg',
#   'rated': 'PASSED',
#   'runtime': '54 min',
#   'title': 'Hypocrites',
#   'type': 'movie',
#   'writers': ['Lois Weber'],
#   'year': '1915'},
#  {'_id': ObjectId('614b754e708918ab180773f7'),
#   'actors': ['Stanley Hunt Sarah Constance Smith Hunt Mrs. George Walkus Paddy '
#              "'Malid"],
#   'awards': '1 win.',
#   'countries': ['USA'],
#   'directors': ['Edward S. Curtis'],
#   'fullPlot': '',
#   'genres': ['Drama History'],
#   'imdb': {'id': '4150', 'rating': '5.8', 'votes': '223'},
#   'languages': ['English'],
#   'metacritic': '',
#   'plot': 'Original advertising for the film describes it as a drama of '
#           'primitive life on the shores of the North Pacific...',
#   'poster': 'https://m.media-amazon.com/images/M/MV5BMjE3ODk0NTAwNF5BMl5BanBnXkFtZTcwNjU2MzYyMQ@@._V1_SX300.jpg',
#   'rated': '',
#   'runtime': '65 min',
#   'title': 'In the Land of the Head Hunters',
#   'type': 'movie',
#   'writers': ['Edward S. Curtis (story)'],
#   'year': '1914'},
#  {'_id': ObjectId('614b754e708918ab180773f8'),
#   'actors': ['Blanche Sweet Henry B. Walthall Mae Marsh Robert Harron'],
#   'awards': '',
#   'countries': ['USA'],
#   'directors': ['D.W. Griffith'],
#   'fullPlot': '"A fascinating work of high artistry ""Judith of Bethulia"" '
#               'will not only rank as an achievement in this country but will '
#               'make foreign producers sit up and take notice. It has a signal '
#               'and imperative message and the technique displayed throughout '
#               'an infinity of detail embracing even the delicate film tinting '
#               'and toning marks an encouraging step in the development of the '
#               'new art. Ancient in story and settings it is modern in '
#               'penetrative interpretation - it is a vivid history of one phase '
#               'of the time it concerns and is redemptive as well as relative a '
#               'lesson from one of those vital struggles that made and unmade '
#               'nations as well as individuals yet it is not without that '
#               'inspiring influence that appeals powerfully to human sense of '
#               'justice. The entire vigorous action of the play works up to the '
#               'personal sacrifice of Judith of Bethulia a perilous chance she '
#               'takes for the sake of the lives and happiness of her people. '
#               'She dares expose herself to overwhelming humiliation and '
#               'dishonor in a challenge of beauty to strength struggles through '
#               'a conversion of sentiment that makes the high crisis more acute '
#               'and sets at defiance the ""better-death-than-dishonor"" '
#               'platitude escaping both through that all-conquering combination '
#               'in a woman great physical beauty joined to lofty intelligence. '
#               'She enters upon a relation of constant peril - only delicate '
#               'treatment saves the situation at times - abandons her native '
#               'purity of conduct and dares her own undoing yet the noble end '
#               'justified the dangerous means and she emerges idealized by her '
#               'people an apotheosis of splendid womanhood. Bethulia is a '
#               'fortified town of Judea guarding a hill pass through which an '
#               'invading Assyrian army must march in order to enter Judea. In '
#               'the town lives Judith a devout young woman of lofty character '
#               'and remarkable beauty when the place is stormed by Holofernes '
#               'at the head of a large army. The fighting before the gate '
#               'brings into action an enormous number of soldiers on both sides '
#               'and those engines of war such as the battering ram and catapult '
#               'which were used by the fighting male of other days under close '
#               'condition of furious combat. One desperate assault after '
#               'another is repelled scaling ladders are thrown down great rocks '
#               'are showered upon the invaders and the wonder is that they keep '
#               'at it. The reason is that Holofernes has a way of torturing and '
#               'killing unsuccessful captains. As officer had better die in the '
#               'thick of battle than return with a confession of defeat. '
#               'Holofernes is as merciless as nature to all who fail. The great '
#               "leader's brutality of his captains when they do not succeed in "
#               'carrying the fortress by storm indicates what the inhabitants '
#               'of Bethulia may expect in the event of capture and serves to '
#               'intensify the clash of character later on - it adds peril to '
#               'the undertaking of Judith when she resolves to sacrifice '
#               'herself for her people. Holofernes after making a horrible '
#               'example of defeated captains by frightful torture resorts to '
#               'strategy. His soldiers have seized the wells from which the '
#               'inhabitants of Bethulia obtained their water supply and their '
#               'leader adopts waiting tactics diverting himself with dancing '
#               'girls to break the tedium. Bethulia is on the verge of famine '
#               'and the besieged are almost ready to surrender the fortress and '
#               'all Judea to the spoilers when Judith goes forth in her finest '
#               'raiment accompanied only by her maid enters the Assryian camp '
#               'and obtains an interview with the merciless Holofernes. Against '
#               'his formidable strength his brutal ferocity and cunning his '
#               'absolute power are matched her fascinating personality directed '
#               'by intelligence and hidden purpose. She is willing to carry '
#               '""her fault on her shoulders like a coronation mantle."" The '
#               "dangerous and difficult situation from this point to Judith's "
#               'terrible triumph and the defeat of the invading Assyrians is '
#               'pictured without loss of force or charm by extreme delicacy of '
#               'treatment. Beauty is constantly asserted by almost reckless '
#               'prodigality in the matter of costume and by the appeal of '
#               'delightful acting. The feminine sweetness and shyness of the '
#               'lovely Judith are intensified by her advances and retreats in '
#               'measuring her sex attractions against his formidable power. She '
#               'is weakened at the critical moment by a sudden flame of passion '
#               'and compassion aroused in her breast but self-control returns '
#               'at a thought of all that is at stake the safety and happiness '
#               'of thousands of her people and she dares be all and do all that '
#               'revolts her finer nature from a deep hatred of injustice and '
#               'wrong meted out to her peace-loving kindred and friends from a '
#               'noble desire to preserve her country and the destinies of her '
#               'race."',
#   'genres': ['Drama'],
#   'imdb': {'id': '4181', 'rating': '7.7', 'votes': '897'},
#   'languages': ['English'],
#   'metacritic': '',
#   'plot': 'A religious woman seeks to save her people from destruction by '
#           'seducing and murdering the enemy leader but her plans get '
#           'complicated once she falls for him.',
#   'poster': 'https://m.media-amazon.com/images/M/MV5BMjA3NjgzMjY1N15BMl5BanBnXkFtZTcwNjAzMjM5OA@@._V1._CR221.883331298828120.533340454101562510551410.0999603271484_SY132_CR5089132_AL_.jpg_V1_SX300.jpg',
#   'rated': '',
#   'runtime': '61 min',
#   'title': 'Judith of Bethulia',
#   'type': 'movie',
#   'writers': ['Thomas Bailey Aldrich (poem) D.W. Griffith Grace Pierce Frank '
#               'E. Woods'],
#   'year': '1914'},
#  {'_id': ObjectId('614b754e708918ab180773f9'),
#   'actors': ["Dan Albert Roscoe 'Fatty' Arbuckle Charles Avery Joe Bordeaux"],
#   'awards': '',
#   'countries': ['USA'],
#   'directors': ['Mack Sennett'],
#   'fullPlot': 'A couple of tramps down on their luck and hungry decide to fake '
#               'an exhibition boxing match for a promoter. Meanwhile Pug a '
#               'good-hearted but boisterous fellow takes on a gang of mashers '
#               'who make unwanted advances to his girlfriend. Impressed by his '
#               'abilities the mashers decide to pass Pug off as Cyclone Flynn '
#               'the champion and enter him in the boxing match. But the real '
#               'Cyclone shows up and he and Pug battle it out in the ring. Soon '
#               'the fight progresses to include pistols rooftop chases and the '
#               'Keystone Kops in hot pursuit.',
#   'genres': ['Short Comedy'],
#   'imdb': {'id': '4194', 'rating': '5.9', 'votes': '720'},
#   'languages': ['English'],
#   'metacritic': '',
#   'plot': 'To show his girl how brave he is Fatty challenges the champion to a '
#           'fight. Charlie referees trying to avoid contact with the two '
#           'monsters.',
#   'poster': '',
#   'rated': 'TV-G',
#   'runtime': '27 min',
#   'title': 'The Knockout',
#   'type': 'movie',
#   'writers': [''],
#   'year': '1914'},
#  {'_id': ObjectId('614b754e708918ab180773fa'),
#   'actors': ['Charles Chaplin Fritz Schade Alice Howell Slim Summerville'],
#   'awards': '',
#   'countries': ['USA'],
#   'directors': ['Charles Chaplin'],
#   'fullPlot': 'Charlie pretends to be a dentist though he is only his '
#               "assistant. When a patient can't stop laughing from the "
#               'anesthesia Charlie knocks him out with a club. He is sent to '
#               'the drug store gets in a fight with a man who (after a brick in '
#               'the face) becomes another patient and pulls the skirt off the '
#               "dentist's wife (who is out walking). At one point Charlie pulls "
#               'a tooth (the wrong one) using enormous pliers.',
#   'genres': ['Short Comedy'],
#   'imdb': {'id': '4210', 'rating': '5.7', 'votes': '739'},
#   'languages': ['English'],
#   'metacritic': '',
#   'plot': 'Charlie pretends to be a dentist though he is only his assistant. '
#           "When a patient can't stop laughing from the anesthesia Charlie "
#           'knocks him out with a club. He is sent to the drug store ...',
#   'poster': 'https://m.media-amazon.com/images/M/MV5BMTk1MjMyNzMxMF5BMl5BanBnXkFtZTYwMTQ3ODc5._V1_SX300.jpg',
#   'rated': '',
#   'runtime': '16 min',
#   'title': 'Laughing Gas',
#   'type': 'movie',
#   'writers': [''],
#   'year': '1914'},
#  {'_id': ObjectId('614b754e708918ab180773fb'),
#   'actors': ['Charles Chaplin Mabel Normand Harry McCoy Chester Conklin'],
#   'awards': '',
#   'countries': ['USA'],
#   'directors': ['Mabel Normand Mack Sennett'],
#   'fullPlot': "Charlie competing with his rival's race car offers Mabel a ride "
#               'on his motorcycle but drops her in a puddle. He next joins some '
#               'dubious characters in abduction of his rival just before the '
#               'race for the Vanderbilt Cup. With her boyfriend locked up in a '
#               'shed Mabel takes his place. Charlie does what he can to '
#               "sabotage the race even causing Mabel's car to overturn.",
#   'genres': ['Short Comedy'],
#   'imdb': {'id': '4277', 'rating': '5.7', 'votes': '433'},
#   'languages': ['English'],
#   'metacritic': '',
#   'plot': "Charlie competing with his rival's race car offers Mabel a ride on "
#           'his motorcycle but drops her in a puddle. He next joins some '
#           'dubious characters in abduction of his rival just before ...',
#   'poster': '',
#   'rated': '',
#   'runtime': '18 min',
#   'title': 'Mabel at the Wheel',
#   'type': 'movie',
#   'writers': [''],
#   'year': '1914'},
#  {'_id': ObjectId('614b754e708918ab180773fc'),
#   'actors': ['Charles Chaplin Mabel Normand Mack Swain Eva Nelson'],
#   'awards': '',
#   'countries': ['USA'],
#   'directors': ['Mack Sennett'],
#   'fullPlot': 'Mabel goes home after being humiliated by a masher whom her '
#               "wimpy husband won't fight. The husband goes off to a bar and "
#               'gets drunk. She buys a boxing dummy hoping it will inspire her '
#               'husband but when he returns he gets in a fight with it taking '
#               'it to be the ladykiller.',
#   'genres': ['Short Comedy'],
#   'imdb': {'id': '4282', 'rating': '5.8', 'votes': '665'},
#   'languages': ['English'],
#   'metacritic': '',
#   'plot': 'Accosted by a masher in the park and unable to motivate husband '
#           'Charlie into taking action Mabel gets him a boxing mannequin to '
#           'sharpen his fighting skills.',
#   'poster': '',
#   'rated': '',
#   'runtime': '17 min',
#   'title': "Mabel's Married Life",
#   'type': 'movie',
#   'writers': ['Charles Chaplin Mabel Normand'],
#   'year': '1914'},
#  {'_id': ObjectId('614b754e708918ab180773fd'),
#   'actors': ['Charles Chaplin'],
#   'awards': '',
#   'countries': ['USA'],
#   'directors': ['Henry Lehrman'],
#   'fullPlot': 'An out-of-work swindler takes a job as a reporter. After '
#               "witnessing a car go over cliff he grabs a rival reporter's "
#               'camera and races to the newspaper office to enter the photo as '
#               "his own. His rival is delayed when he gets caught in a woman's "
#               'bedroom by her jealous husband. The swindler follows the '
#               "distribution of the paper containing his 'scoop' around town "
#               'where he is once again chased by the rival reporter. Both end '
#               'up on the cow-catcher of a streetcar.',
#   'genres': ['Short Comedy'],
#   'imdb': {'id': '4288', 'rating': '5.5', 'votes': '1115'},
#   'languages': ['English'],
#   'metacritic': '',
#   'plot': 'An out-of-work swindler takes a job as a reporter. After witnessing '
#           "a car go over cliff he grabs a rival reporter's camera and races to "
#           'the newspaper office to enter the photo as his own. ...',
#   'poster': 'https://m.media-amazon.com/images/M/MV5BMjI0Nzg5MjYxMF5BMl5BanBnXkFtZTcwMzgxODQ4Mg@@._V1._CR10278253333_SY132_CR5089132_AL_.jpg_V1_SX300.jpg',
#   'rated': 'TV-G',
#   'runtime': '13 min',
#   'title': 'Making a Living',
#   'type': 'movie',
#   'writers': [''],
#   'year': '1914'},
#  {'_id': ObjectId('614b754e708918ab180773fe'),
#   'actors': ['Carlyle Blackwell Doris Kenyon Edgar Norton Fraunie Fraunholz'],
#   'awards': '',
#   'countries': ['USA'],
#   'directors': ['Alice Guy'],
#   'fullPlot': 'An abused woman finds love in the arms of a famous novelist.',
#   'genres': ['Short Comedy Drama'],
#   'imdb': {'id': '4413', 'rating': '6.9', 'votes': '66'},
#   'languages': ['English'],
#   'metacritic': '',
#   'plot': 'An abused woman finds love in the arms of a famous novelist.',
#   'poster': 'https://m.media-amazon.com/images/M/MV5BMjI3Mjc1OTc3OV5BMl5BanBnXkFtZTgwOTQ2Njk1MDE@._V1_SX300.jpg',
#   'rated': 'UNRATED',
#   'runtime': '40 min',
#   'title': 'The Ocean Waif',
#   'type': 'movie',
#   'writers': [''],
#   'year': '1916'}]
